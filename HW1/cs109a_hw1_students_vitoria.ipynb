# %% [markdown]
# <h1 style="padding-top: 25px;padding-bottom: 25px;text-align: left; padding-left: 10px; background-color: #DDDDDD;
#     color: black;"> <img style="float: left; padding-right: 10px; width: 45px" src="https://raw.githubusercontent.com/Harvard-IACS/2018-CS109A/master/content/styles/iacs.png"> CS109A Introduction to Data Science </h1>
#
# ## Homework 1: Data Collection, Parsing, and Quick Analyses
#
# **Harvard University**<br/>
# **Fall 2021**<br/>
# **Instructors**: Pavlos Protopapas and Natesh Pillai<br/>
# **Names**: Kimon Vogt and Ana Vitoria Rodrigues Lima<br/>
#
#
# <hr style='height:2px'>

# %%
## RUN THIS CELL TO GET THE RIGHT FORMATTING 
import requests
from IPython.core.display import HTML
styles = requests.get("https://raw.githubusercontent.com/Harvard-IACS/2021-CS109A/master/themes/static/css/cs109.css").text
HTML(styles)
# Out:
# <style>
# blockquote { background: #AEDE94; }
# h1 {
#     padding-top: 25px;
#     padding-bottom: 25px;
#     text-align: left;
#     padding-left: 10px;
#     background-color: #63ACBE;
#     color: black;
# }
# h2 {
#     padding-top: 10px;
#     padding-bottom: 10px;
#     text-align: left;
#     padding-left: 5px;
#     background-color: #EEEEEE;
#     color: black;
# }
#
# div.exercise {
# 	background-color: #f8b4ab;
# 	border-color: #E9967A;
# 	border-left: 5px solid #601A4A;
# 	padding: 0.5em;
# }
#
# div.exercise-r {
# 	background-color: #ffd0d0;
# 	border-color: #E9967A;
# 	border-left: 5px solid #601A4A;
# 	padding: 0.5em;
# }
#
#
# span.sub-q {
# 	font-weight: bold;
# }
# div.theme {
# 	background-color: #63ACBE;
# 	border-color: #E9967A;
# 	border-left: 5px solid #601A4A;
# 	padding: 0.5em;
# 	font-size: 18pt;
# }
# div.gc {
# 	background-color: #AEDE94;
# 	border-color: #E9967A;
# 	border-left: 5px solid #601A4A;
# 	padding: 0.5em;
# 	font-size: 12pt;
# }
# p.q1 {
#     padding-top: 5px;
#     padding-bottom: 5px;
#     text-align: left;
#     padding-left: 5px;
#     background-color: #EEEEEE;
#     color: black;
# }
# header {
#    padding-top: 35px;
#     padding-bottom: 35px;
#     text-align: left;
#     padding-left: 10px;
#     background-color: #DDDDDD;
#     color: black;
# }
# span.emph {
# 	color: #601A4A;
# 	font-weight: bold;
# }
#
# </style>

# %% [markdown]
# ## Overview
#
# In this homework, your goal is to learn how to acquire, parse, clean, and analyze data. Toward this goal, we will address certain questions about COVID, and you will scrape data directly from a website. For the remainder of the semester, we will provide you data files directly; however, since real-world problems often require gathering information from a variety of sources, including the Internet, web scraping is a highly useful skill to have.
#
# ### Instructions
# - To submit your assignment, follow the instructions given in Canvas.
#
# ### Learning Objectives
# - Get started using [Jupyter Notebooks](https://jupyter.org/), which are incredibly popular, powerful, and will be our medium of programming for the duration of CS109A and CS109B.
# - Become familiar with how to access and use data from various sources (i.e., web scraping and directly from files).
# - Gain experience with data exploration and simple analysis.
# - Become comfortable with [pandas](https://pandas.pydata.org/) as a means of storing and working with data.
# - Reflect on what further analysis you may wish to do with this data. For example, given the material we've covered so far, what *more* do you wish you had the ability to do (e.g., modelling, prediction, etc). That is, think about questions you may have about the data, and try to imagine what types of tools you might need to help answer your questions.
#
# ### Notes
# - Exercise **responsible scraping**. Web servers can become slow or unresponsive if they receive too many requests from the same source in a short amount of time. In your code, use a delay of 2 seconds between requests. This helps to not get blocked by the target website -- imagine how frustrating it would be to have this occur. Section 1 of this homework involves saving the scraped web pages to your local machine. Thus, after completing Section 1, you do not need to re-scrape any of the pages, unless you wish to occasionally grab the latest data.
#
# - <span style='color:purple'>**Web scraping requests can take several minutes**</span>. This is another reason why you should not wait until the last minute to do this homework.
# - As you run a Jupyter Notebook, it maintains a running state of memory. Thus, <span style='color:purple'>the order in which you run cells matters</span> and plays a crucial role; it can be easy to make mistakes based on *when* you run different cells as you develop and test your code. Before submitting every Jupyter Notebook homework assignment, be sure to restart your Jupyter Notebook and run the entire notebook from scratch, all at once (i.e., "Kernel -> Restart & Run All"). Just make sure to not re-run the time intensive tasks unnecessarily. In this notebook for example, you could declare a variable to act as a 'setting' and use some controll logic to prevent a re-scrap from happening when not desired.
#
# - We will be working with COVID data. COVID has impacted everyone in the world, and naturally some people have been greatly more affected than others. We, the teaching staff, are sensitive to this, empathize, and understand that working with COVID data may be unsettling to some. We apologize for any discomfort this may cause. Our intent with this assignment is purely pedagogical, and we'd like to remind students that data science and machine learning can be used to provide insights that can be used for good and invoke change. Toward this goal, parts of the homework are intended to shed light on the unfortunate, widespread inequality that exists. So, while this data may be unsettling, our aim is for the learned skills addressed here -- and in all future assignments -- to provide you with knowledge and confidence to do good work.

# %% [markdown]
# ## 1. Obtaining Data (17 points)
#
# For any given situation or scenario that we wish to understand, we will rely on having relevant data. Here, we are interested in the degree to which the SARS-CoV-2 virus has affected United States citizens (SARS-CoV-2 is the virus that causes the COVID-19 disease). The Centers for Disease Control and Prevention (CDC) provides relevant data from USAFacts.org that includes the number of confirmed COVID-19 cases on a per-county basis. Visit https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/. At the bottom of the web page, in a blue table, you should see a list of every state, each of which has its own web page.
#
# In this exercise, we will focus on automating the downloading of each state's data with [Requests](https://docs.python-requests.org/en/master/) and then manipulating it with [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/).
#
# But first, as we will do for every Jupyter Notebook, let's import necessary packages that we will use throughout the notebook (i.e., run the cell below).

# %%
# import the necessary libraries
import re
import requests
import pandas as pd
import numpy as np
from time import sleep
from bs4 import BeautifulSoup
import pickle # for loading a dictionary from disk
from typing import Optional # typehint that value can also be None

# NOTE: files will be saved to this directory, so you need to ensure
# that it exists on your system first (it should be visible from the
# directory of where you are running this Notebook file)
# i.e.,
# >> ls
# cs109a_hw1_student.ipynb
# data/
# state_data/
#state_dir = "AC209a/HW1/state_data/"
state_dir = 'state_data/'

# %%
# we define this for convenience, as every state's url begins with this prefix
base_url = 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/'

# %% [markdown]
# <div class='exercise'><b> Exercise 1.1 [1 pt]: Fetching Website data via Requests</b>
#
# Fetch the web page located at `base_url` and save the request's returned object (a Response object) to a variable named `home_page`.
# </div>

# %%
# YOUR CODE HERE

home_page = requests.get(base_url)

# END OF YOUR CODE HERE

# %% [markdown]
# <div class='exercise'><b>Exercise 1.2 [2 pts]:</b> In the cell below:
#
# - Write a line of code that prints to the screen the status of `home_page` (the web page's returned object). You should receive a code of 200 if the request was successful; then,
#
# - **When working with Jupyter Notebooks, avoiding unnecessarily long output in is essential.** Write code that prints the first 10,000 characters from the contents of `home_page` and [enable scolling output for the cell](https://www.youtube.com/watch?v=U4usAUZCv_c&t=1s).</div>

# %%
# YOUR CODE HERE

print(home_page)
raw_home=home_page.text
print(home_page.text[:10000])

# END OF YOUR CODE HERE
# Out:
# <Response [200]>
# <!doctype html><html lang="en"><head><script type="text/javascript">window.NREUM||(NREUM={});NREUM.info = {"agent":"","beacon":"bam-cell.nr-data.net","errorBeacon":"bam-cell.nr-data.net","licenseKey":"NRJS-c11b817f31177e0b4d1","applicationID":"1475026924","applicationTime":1880.271443,"transactionName":"ZwZaNUEFVhZZAkNRWl5Mdg5BCVkJURtSXGBCChdL","queueTime":0,"ttGuid":"e640ef2bbcc3dd09","agentToken":null}; (window.NREUM||(NREUM={})).loader_config={licenseKey:"NRJS-c11b817f31177e0b4d1",applicationID:"1475026924"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(){}function i(t,e,n){return function(){return o(t,[u.now()].concat(f(arguments)),e?null:this,n),e?void 0:this}}var o=t("handle"),a=t(8),f=t(9),c=t("ee").get("tracer"),u=t("loader"),s=NREUM;"undefined"==typeof window.newrelic&&(newrelic=s);var d=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],p="api-",l=p+"ixn-";a(d,function(t,e){s[e]=i(p+e,!0,"api")}),s.addPageAction=i(p+"addPageAction",!0),s.setCurrentRouteName=i(p+"routeName",!0),e.exports=newrelic,s.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(t,e){var n={},r=this,i="function"==typeof e;return o(l+"tracer",[u.now(),t,n],r),function(){if(c.emit((i?"":"no-")+"fn-start",[u.now(),r,i],n),i)try{return e.apply(this,arguments)}catch(t){throw c.emit("fn-err",[arguments,this,t],n),t}finally{c.emit("fn-end",[u.now()],n)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(t,e){m[e]=i(l+e)}),newrelic.noticeError=function(t,e){"string"==typeof t&&(t=new Error(t)),o("err",[t,u.now(),!1,e])}},{}],2:[function(t,e,n){function r(t){if(NREUM.init){for(var e=NREUM.init,n=t.split("."),r=0;r<n.length-1;r++)if(e=e[n[r]],"object"!=typeof e)return;return e=e[n[n.length-1]]}}e.exports={getConfiguration:r}},{}],3:[function(t,e,n){function r(){return f.exists&&performance.now?Math.round(performance.now()):(o=Math.max((new Date).getTime(),o))-a}function i(){return o}var o=(new Date).getTime(),a=o,f=t(10);e.exports=r,e.exports.offset=a,e.exports.getLastTimestamp=i},{}],4:[function(t,e,n){function r(t){return!(!t||!t.protocol||"file:"===t.protocol)}e.exports=r},{}],5:[function(t,e,n){function r(t,e){var n=t.getEntries();n.forEach(function(t){"first-paint"===t.name?d("timing",["fp",Math.floor(t.startTime)]):"first-contentful-paint"===t.name&&d("timing",["fcp",Math.floor(t.startTime)])})}function i(t,e){var n=t.getEntries();n.length>0&&d("lcp",[n[n.length-1]])}function o(t){t.getEntries().forEach(function(t){t.hadRecentInput||d("cls",[t])})}function a(t){if(t instanceof m&&!g){var e=Math.round(t.timeStamp),n={type:t.type};e<=p.now()?n.fid=p.now()-e:e>p.offset&&e<=Date.now()?(e-=p.offset,n.fid=p.now()-e):e=p.now(),g=!0,d("timing",["fi",e,n])}}function f(t){"hidden"===t&&d("pageHide",[p.now()])}if(!("init"in NREUM&&"page_view_timing"in NREUM.init&&"enabled"in NREUM.init.page_view_timing&&NREUM.init.page_view_timing.enabled===!1)){var c,u,s,d=t("handle"),p=t("loader"),l=t(7),m=NREUM.o.EV;if("PerformanceObserver"in window&&"function"==typeof window.PerformanceObserver){c=new PerformanceObserver(r);try{c.observe({entryTypes:["paint"]})}catch(v){}u=new PerformanceObserver(i);try{u.observe({entryTypes:["largest-contentful-paint"]})}catch(v){}s=new PerformanceObserver(o);try{s.observe({type:"layout-shift",buffered:!0})}catch(v){}}if("addEventListener"in document){var g=!1,h=["click","keydown","mousedown","pointerdown","touchstart"];h.forEach(function(t){document.addEventListener(t,a,!1)})}l(f)}},{}],6:[function(t,e,n){function r(t,e){if(!i)return!1;if(t!==i)return!1;if(!e)return!0;if(!o)return!1;for(var n=o.split("."),r=e.split("."),a=0; ...

# %% [markdown]
# <div class='exercise'><b> Exercise 1.3 [1 pt]:</b>
#
# In the cell below, create a new BeautifulSoup object that parses the `home_page` as an HTML document (can be done with 1 line of code)</div>

# %%
# YOUR CODE HERE

soup = BeautifulSoup(raw_home, 'html.parser')
soup

pretty_soup= soup.prettify()
pretty_soup


# END OF YOUR CODE HERE
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n <head>\n  <script type="text/javascript">\n   window.NREUM||(NREUM={});NREUM.info = {"agent":"","beacon":"bam-cell.nr-data.net","errorBeacon":"bam-cell.nr-data.net","licenseKey":"NRJS-c11b817f31177e0b4d1","applicationID":"1475026924","applicationTime":1880.271443,"transactionName":"ZwZaNUEFVhZZAkNRWl5Mdg5BCVkJURtSXGBCChdL","queueTime":0,"ttGuid":"e640ef2bbcc3dd09","agentToken":null}; (window.NREUM||(NREUM={})).loader_config={licenseKey:"NRJS-c11b817f31177e0b4d1",applicationID:"1475026924"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(){}function i(t,e,n){return function(){return o(t,[u.now()].concat(f(arguments)),e?null:this,n),e?void 0:this}}var o=t("handle"),a=t(8),f=t(9),c=t("ee").get("tracer"),u=t("loader"),s=NREUM;"undefined"==typeof window.newrelic&&(newrelic=s);var d=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],p="api-",l=p+"ixn-";a(d,function(t,e){s[e]=i(p+e,!0,"api")}),s.addPageAction=i(p+"addPageAction",!0),s.setCurrentRouteName=i(p+"routeName",!0),e.exports=newrelic,s.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(t,e){var n={},r=this,i="function"==typeof e;return o(l+"tracer",[u.now(),t,n],r),function(){if(c.emit((i?"":"no-")+"fn-start",[u.now(),r,i],n),i)try{return e.apply(this,arguments)}catch(t){throw c.emit("fn-err",[arguments,this,t],n),t}finally{c.emit("fn-end",[u.now()],n)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(t,e){m[e]=i(l+e)}),newrelic.noticeError=function(t,e){"string"==typeof t&&(t=new Error(t)),o("err",[t,u.now(),!1,e])}},{}],2:[function(t,e,n){function r(t){if(NREUM.init){for(var e=NREUM.init,n=t.split("."),r=0;r<n.length-1;r++)if(e=e[n[r]],"object"!=typeof e)return;return e=e[n[n.length-1]]}}e.exports={getConfiguration:r}},{}],3:[function(t,e,n){function r(){return f.exists&&performance.now?Math.round(performance.now()):(o=Math.max((new Date).getTime(),o))-a}function i(){return o}var o=(new Date).getTime(),a=o,f=t(10);e.exports=r,e.exports.offset=a,e.exports.getLastTimestamp=i},{}],4:[function(t,e,n){function r(t){return!(!t||!t.protocol||"file:"===t.protocol)}e.exports=r},{}],5:[function(t,e,n){function r(t,e){var n=t.getEntries();n.forEach(function(t){"first-paint"===t.name?d("timing",["fp",Math.floor(t.startTime)]):"first-contentful-paint"===t.name&&d("timing",["fcp",Math.floor(t.startTime)])})}function i(t,e){var n=t.getEntries();n.length>0&&d("lcp",[n[n.length-1]])}function o(t){t.getEntries().forEach(function(t){t.hadRecentInput||d("cls",[t])})}function a(t){if(t instanceof m&&!g){var e=Math.round(t.timeStamp),n={type:t.type};e<=p.now()?n.fid=p.now()-e:e>p.offset&&e<=Date.now()?(e-=p.offset,n.fid=p.now()-e):e=p.now(),g=!0,d("timing",["fi",e,n])}}function f(t){"hidden"===t&&d("pageHide",[p.now()])}if(!("init"in NREUM&&"page_view_timing"in NREUM.init&&"enabled"in NREUM.init.page_view_timing&&NREUM.init.page_view_timing.enabled===!1)){var c,u,s,d=t("handle"),p=t("loader"),l=t(7),m=NREUM.o.EV;if("PerformanceObserver"in window&&"function"==typeof window.PerformanceObserver){c=new PerformanceObserver(r);try{c.observe({entryTypes:["paint"]})}catch(v){}u=new PerformanceObserver(i);try{u.observe({entryTypes:["largest-contentful-paint"]})}catch(v){}s=new PerformanceObserver(o);try{s.observe({type:"layout-shift",buffered:!0})}catch(v){}}if("addEventListener"in document){var g=!1,h=["click","keydown","mousedown","pointerdown","touchstart"];h.forEach(function(t){document.addEventListener(t,a,!1)})}l(f)}},{}],6:[function(t,e,n){function r(t,e){if(!i)return!1;if(t!==i)return!1;if(!e)return!0;if(!o)return!1;for(var n=o.split("."),r=e. ...

# %% [markdown]
# <div class='exercise'><b> Exercise 1.4 [8 pts]:</b>
#
# In the cell below, write code that uses the BeautifulSoup object to parse through the home page in order to extract the link for every state. Feel free to use [Regular Expressions]('https://docs.python.org/3/library/re.html'), in conjunction with any BeautifulSoup parsing. Specifically, the goal is to populate a `state_urls` [dictionary]('https://docs.python.org/3/tutorial/datastructures.html#dictionaries') by setting each key to be the state name and the value to be the full URL. When complete, there will be 51 keys (50 states + 1 for DC).
#
# ### AS A CRITICAL EXAMPLE:
# Within `state_urls`, one of your <key, value> pairs should be:
#
# ``"District of Columbia" : "https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/district-of-columbia"``
#
# The casing here is **incredibly** important because later, in Exercise 4, you will merge your data with another dataset that has casing of this form. Thus, our key here should be `District of Columbia` and not `District Of Columbia` or `district-of-columbia`.
#
#
# **NOTES:**
# - There are _many_ solutions, but you may find it easiest to use Regular Expression(s)
# - Pay attention to the casing example above, so that your later exercises go smoothly.
# - Some HTML tag attributes may change over time. It your code stops working, make sure you are not targeting such ephemeral elements ('jss' class attributes are a common culprit)
# </div>

# %%
import urllib 

# YOUR CODE HERE
state_urls = {}
pretty_soup = soup.prettify()

list_a_tag = soup.select("th a")
list_a_tag

for i in list_a_tag:
    state_urls[i.text]=urllib.parse.urljoin(base_url, i.get('href'))

state_urls
# END OF YOUR CODE HERE
# Out:
# {'Alabama': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/alabama',
#  'Alaska': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/alaska',
#  'Arizona': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/arizona',
#  'Arkansas': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/arkansas',
#  'California': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/california',
#  'Colorado': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/colorado',
#  'Connecticut': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/connecticut',
#  'Delaware': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/delaware',
#  'District of Columbia': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/district-of-columbia',
#  'Florida': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/florida',
#  'Georgia': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/georgia',
#  'Hawaii': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/hawaii',
#  'Idaho': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/idaho',
#  'Illinois': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/illinois',
#  'Indiana': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/indiana',
#  'Iowa': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/iowa',
#  'Kansas': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/kansas',
#  'Kentucky': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/kentucky',
#  'Louisiana': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/louisiana',
#  'Maine': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/maine',
#  'Maryland': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/maryland',
#  'Massachusetts': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/massachusetts',
#  'Michigan': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/michigan',
#  'Minnesota': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/minnesota',
#  'Mississippi': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/mississippi',
#  'Missouri': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/missouri',
#  'Montana': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/montana',
#  'Nebraska': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/nebraska',
#  'Nevada': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/nevada',
#  'New Hampshire': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/new-hampshire',
#  'New Jersey': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/new-jersey',
#  'New Mexico': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/new-mexico',
#  'New York': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/new-york',
#  'North Carolina': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/north-carolina',
#  'North Dakota': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/north-dakota',
#  'Ohio': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/ohio',
#  'Oklahoma': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/oklahoma',
#  'Oregon': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/oregon',
#  'Pennsylvania': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/pennsylvania',
#  'Rhode Island': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/rhode-island',
#  'South Carolina': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/south-carolina',
#  'South Dakota': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/south-dakota',
#  'Tennessee': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/tennessee',
#  'Texas': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/texas',
#  'Utah': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/utah',
#  'Vermont': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/vermont',
#  'Virginia': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/virginia',
#  'Washington': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/washington',
#  'West Virginia': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/west-virginia',
#  'Wisconsin': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/wisconsin',
#  'Wyoming': 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/wyoming'}

# %% [markdown]
# Run the cell below to help ensure your formatting is correct and has 51 <key, value> pairs.

# %%
# SANITY CHECK
if len(state_urls.keys()) != 51 or \
state_urls["District of Columbia"] != "https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/district-of-columbia":
    print("** 1.4 is incorrect")
else:
    print("** 1.4 might be correct")
# Out:
# ** 1.4 might be correct

# %% [markdown]
# We wish to use the data without having to re-download it every time. So, let's save each webpage to our local hard drive. **NOTE: It's probably okay to download all of the state web pages a few times a day, but it's safer to keep it to a minimum.**

# %% [markdown]
# <div class='exercise'><b> Exercise 1.5 [5 pts]:</b>
#
# In the cell below, we will iterate through all <key, value> items in `state_urls`. Your job is to make a web request for each URL and save the **contents** out to a file on your hard drive (use `state_dir`, defined above, as the prefix to the path.)
#
# **NOTES:**
# - **Leave a 2 second pause between requests**
# - You should be saving to a file the actual content of the webpage, not a BeautifulSoup object. That is, you should be able to open the saved files in an editor and see the HTML code, just as you could if you were to view the webpage in your browser and click 'View Page Source'.
# - See [official Python documentation](https://docs.python.org/3/tutorial/inputoutput.html#reading-and-writing-files) for details on how to read/write files to disk
# - You should have saved 51 different files to your hard drive.
# - **Once you have written the files you can comment out this cell. This will save time and prevent you from making unnecessary requests when you restart the kernel & re-run all cells in the noteboook before submitting (as you should!)**
# </div>

# %%
# 1.5 (5 pts) -- save each webpage to disk
#state_dir = "/state_data/"

import os as os
import sys

for state, url in state_urls.items():
    # YOUR CODE HERE
    name_of_file = state
    completeName= os.path.join(state_dir, name_of_file)
    file=open(completeName,'w')
    toFile = requests.get(url).text
    
    file.write(toFile)
    file.close()

    # END OF YOUR CODE HERE
    
    sleep(2) # LEAVE THIS IN

# %% [markdown]
# ## 2. Loading and Exploring Data (22 pts)
# Now, let's actually use the data! Fortunately, it's saved to our local machine, so we don't need to re-crawl the data every time we wish to access it. We want you to understand that [pandas](https://pandas.pydata.org/) is a library of useful data structures and operations, but we also wish to remind you that it isn't magic and it isn't the _only_ way to do Data Science; it's just a tool to help, and you could do the same operations without pandas. Thus, here we ask you to perform a few operations without using pandas, and then in Exercise 3 we will use pandas.
#
# **Terminology Notice:** In the United States, every state is comprised of many **counties.** You can think of a **county** as being a pretty large district.

# %% [markdown]
# First, run the cell below to construct `state_info`
# This is an example of a Python [list comprehension](https://docs.python.org/3/tutorial/datastructures.html#list-comprehensions).

# %%
state_info = [(state, state_dir + state) for state in state_urls.keys()]
print(state_info)
# Out:
# [('Alabama', 'state_data/Alabama'), ('Alaska', 'state_data/Alaska'), ('Arizona', 'state_data/Arizona'), ('Arkansas', 'state_data/Arkansas'), ('California', 'state_data/California'), ('Colorado', 'state_data/Colorado'), ('Connecticut', 'state_data/Connecticut'), ('Delaware', 'state_data/Delaware'), ('District of Columbia', 'state_data/District of Columbia'), ('Florida', 'state_data/Florida'), ('Georgia', 'state_data/Georgia'), ('Hawaii', 'state_data/Hawaii'), ('Idaho', 'state_data/Idaho'), ('Illinois', 'state_data/Illinois'), ('Indiana', 'state_data/Indiana'), ('Iowa', 'state_data/Iowa'), ('Kansas', 'state_data/Kansas'), ('Kentucky', 'state_data/Kentucky'), ('Louisiana', 'state_data/Louisiana'), ('Maine', 'state_data/Maine'), ('Maryland', 'state_data/Maryland'), ('Massachusetts', 'state_data/Massachusetts'), ('Michigan', 'state_data/Michigan'), ('Minnesota', 'state_data/Minnesota'), ('Mississippi', 'state_data/Mississippi'), ('Missouri', 'state_data/Missouri'), ('Montana', 'state_data/Montana'), ('Nebraska', 'state_data/Nebraska'), ('Nevada', 'state_data/Nevada'), ('New Hampshire', 'state_data/New Hampshire'), ('New Jersey', 'state_data/New Jersey'), ('New Mexico', 'state_data/New Mexico'), ('New York', 'state_data/New York'), ('North Carolina', 'state_data/North Carolina'), ('North Dakota', 'state_data/North Dakota'), ('Ohio', 'state_data/Ohio'), ('Oklahoma', 'state_data/Oklahoma'), ('Oregon', 'state_data/Oregon'), ('Pennsylvania', 'state_data/Pennsylvania'), ('Rhode Island', 'state_data/Rhode Island'), ('South Carolina', 'state_data/South Carolina'), ('South Dakota', 'state_data/South Dakota'), ('Tennessee', 'state_data/Tennessee'), ('Texas', 'state_data/Texas'), ('Utah', 'state_data/Utah'), ('Vermont', 'state_data/Vermont'), ('Virginia', 'state_data/Virginia'), ('Washington', 'state_data/Washington'), ('West Virginia', 'state_data/West Virginia'), ('Wisconsin', 'state_data/Wisconsin'), ('Wyoming', 'state_data/Wyoming')]

# %% [markdown]
# <div class='exercise'><b> Exercise 2.1 [10 pts]: Parsing and storing data</b>
#
# Complete the `load_covid_data()` function, which:
#
# - Takes as input `state_info`, which is a list of [tuples](https://docs.python.org/3.3/library/stdtypes.html?highlight=tuple#tuple): (state name, path to the corresponding file)
# - Parses the contents of the file and extracts for **each county**:
#     - 7 day average case
#     - 7 day average deaths
#     - \# of confirmed cases (total)
#     - \# of deaths
#     - Stores the above 4 pieces of data above as well as **population** in a **non-pandas** data structure named `covid_data` **for every county across every state**
# - Returns `covid_data`
#     <font color='blue'>
#
#
# **NOTES:**
# - **Attention: the population variable not in `state_info`. More on info on where to get this value is found in the green block below**
# - To be clear, as of September 7, 2021, the webpage for Alabama currently lists 67 counties. District of Columbia has 1 county, and Wyoming has 23. Here we are asking you to store in `covid_data` *all counties* across every state. So, later, if we were wished to access just Wyoming's information, you could easily retrieve such for each of its 23 counties, or the info for any of the 67 counties in Alabama.
# - `covid_data` **must not be a PANDAS data structure;** it must use a combination of lists and/or dictionaries. It's up to you to decide how to organize this, e.g., a lists of lists of lists, or a list of dictionaries, or a dictionary of dictionaries, or a dictionary of lists of lists, etc. A guiding decision should be ease of access for computing basic stats (Exercises 2.2, 2.3, and 2.4)
# - For the duration of our using this data for the homework, be sure to **properly store the data with the correct data types;** that is, counts should be represented as Integers and rates should be represented as Floats. For example:
#     - \# of confirmed cases (total) should be an **Integer**
#     - \# of deaths should be an **Integer**
#     - \# of confirmed cases (per 100k) should be a **Float** (we haven't created this feature yet!)
#     - 7 day average cases should be an **Integer** (you'd think an average should be a float but the values you scrapped were rounded to the nearest int)
# </div>

# %% [markdown]
# <div style='background-color:lightgreen;padding:15px'>
#     <strong>Injecting population data</strong>
#
#
# The table on usafacts.org you've just scrapped originally had additional columns related to county population. But these have recently been removed! We'd like you to be able to utilize the population data in the following section but also use up-to-date COVID data (so the [Internet Archive](https://archive.org/) was not an option). And, though this information is available elsewhere on usafacts.org, we've decided that you've already done enough web scraping for one HW. So below we've provided a [kludge](https://en.wikipedia.org/wiki/Kludge#Computer_science).
#
# `population_dict` is a nested dictionary. The keys are states whose values are _themselves_ dictionaries. Those '_inner_' dictionaries' keys are counties and their values are populations. It looks like this:
# ```python
# {'Alabama': {'Autauga County': 55869,
#              'Baldwin County': 223234,
#            ...
# 'Wyoming': {'Albany County': 38880,
#             'Big Horn County': 11790,
#             ...
# ```
#
# To get at a population you could use double dictionary indexing like `population_dict['Alabama']['Autauga County']`
#
# But not all of the counties you've scrapped have population data in this dictionary. So we've provided a helper function, `get_pop`, that will return `None` if the county data was not found. Use `get_pop` to inject popoulation data into your `covid_data` as you build it up in the `load_covid_data` function you'll implement below.
#
# **Final Note: you should _ignore counties with missing population data or populations of 0_. Simply do not add them to `covid_data` as it is constructed.**
# </div>

# %%
# load additional county population data as a nested dictionary
# you can read about this strange .pkl 'pickle' file here
# https://docs.python.org/3/library/pickle.html
with open('population.pkl', 'rb') as f:
    population_dict = pickle.load(f)
    

# not sure what's happening with the data types in the function header?
# check out: https://docs.python.org/3/library/typing.html#module-typing
def get_pop(state: str, county: str) -> Optional[int]:
    '''
    returns population of country, state (int)
    If county or state not found, returns None
    Example: get_pop('Alabama', 'Autauga County')
    '''
    try:
        return population_dict.get(state).get(county)
    except AttributeError:
        print('incorrect state name!')
        return None

# %%
def load_covid_data(state_info):
    covid_data = {}
    # YOUR CODE HERE
    for i in range(len(state_info)):
        state_website_content = BeautifulSoup(open(state_info[i][1],'r').read(), 'html.parser')
        table_node = state_website_content.select('table')[1]
        th_list = table_node.select('th a')
        td_list = table_node.select('td')
        print('State:', state_info[i][0])
        print('State file:', state_info[i][1])
        print("Number of headers in table:", len(table_node.select('th a')))
        print("Number of data in table:", len(table_node.select('td')))
        
        covid_data[state_info[i][0]] = {}
        for j, th in enumerate(th_list):
            if get_pop(state_info[i][0], th.text):
                covid_data[state_info[i][0]][th.text]={}
                #print(th.text)
                #do a loop with all the data related to that county
                #for k in range(4):
                covid_data[state_info[i][0]][th.text]['seven_d_cases']= int(td_list[4*j ].text.replace(',', ''))
                covid_data[state_info[i][0]][th.text]['seven_d_deaths']= int(td_list[4*j + 1].text.replace(',', ''))
                covid_data[state_info[i][0]][th.text]['cases']= int(td_list[4*j + 2].text.replace(',', ''))
                covid_data[state_info[i][0]][th.text]['deaths']= int(td_list[4*j + 3].text.replace(',', ''))
        
    return covid_data

# %% [markdown]
# Run the cell below (no changes necessary) to execute your code above

# %%
covid_data = load_covid_data(state_info)
# Out:
# State: Alabama
# State file: state_data/Alabama
# Number of headers in table: 67
# Number of data in table: 268
# State: Alaska
# State file: state_data/Alaska
# Number of headers in table: 29
# Number of data in table: 116
# State: Arizona
# State file: state_data/Arizona
# Number of headers in table: 15
# Number of data in table: 60
# State: Arkansas
# State file: state_data/Arkansas
# Number of headers in table: 75
# Number of data in table: 300
# State: California
# State file: state_data/California
# Number of headers in table: 58
# Number of data in table: 232
# State: Colorado
# State file: state_data/Colorado
# Number of headers in table: 64
# Number of data in table: 256
# State: Connecticut
# State file: state_data/Connecticut
# Number of headers in table: 8
# Number of data in table: 32
# State: Delaware
# State file: state_data/Delaware
# Number of headers in table: 3
# Number of data in table: 12
# State: District of Columbia
# State file: state_data/District of Columbia
# Number of headers in table: 1
# Number of data in table: 4
# State: Florida
# State file: state_data/Florida
# Number of headers in table: 67
# Number of data in table: 268
# State: Georgia
# State file: state_data/Georgia
# Number of headers in table: 159
# Number of data in table: 636
# State: Hawaii
# State file: state_data/Hawaii
# Number of headers in table: 5
# Number of data in table: 20
# State: Idaho
# State file: state_data/Idaho
# Number of headers in table: 44
# Number of data in table: 176
# State: Illinois
# State file: state_data/Illinois
# Number of headers in table: 102
# Number of data in table: 408
# State: Indiana
# State file: state_data/Indiana
# Number of headers in table: 92
# Number of data in table: 368
# State: Iowa
# State file: state_data/Iowa
# Number of headers in table: 99
# Number of data in table: 396
# State: Kansas
# State file: state_data/Kansas
# Number of headers in table: 105
# Number of data in table: 420
# State: Kentucky
# State file: state_data/Kentucky
# Number of headers in table: 120
# Number of data in table: 480
# State: Louisiana
# State file: state_data/Louisiana
# Number of headers in table: 64
# Number of data in table: 256
# State: Maine
# State file: state_data/Maine
# Number of headers in table: 16
# Number of data in table: 64
# State: Maryland
# State file: state_data/Maryland
# Number of headers in table: 24
# Number of data in table: 96
# State: Massachusetts
# State file: state_data/Massachusetts
# Number of headers in table: 14
# Number of data in table: 56
# State: Michigan
# State file: state_data/Michigan
# Number of headers in table: 83
# Number of data in table: 332
# State: Minnesota
# State file: state_data/Minnesota
# Number of headers in table: 87
# Number of data in table: 348
# State: Mississippi
# State file: state_data/Mississippi
# Number of headers in table: 82
# Number of data in table: 328
# State: Missouri
# State file: state_data/Missouri
# Number of headers in table: 115
# Number of data in table: 460
# State: Montana
# State file: state_data/Montana
# Number of headers in table: 56
# Number of data in table: 224
# State: Nebraska
# State file: state_data/Nebraska
# Number of headers in table: 93
# Number of data in table: 372
# State: Nevada
# State file: state_data/Nevada
# Number of headers in table: 17
# Number of data in table: 68
# State: New Hampshire
# State file: state_data/New Hampshire
# Number of headers in table: 10
# Number of data in table: 40
# State: New Jersey
# State file: state_data/New Jersey
# Number of headers in table: 21
# Number of data in table: 84
# State: New Mexico
# State file: state_data/New Mexico
# Number of headers in table: 33
# Number of data in table: 132
# State: New York
# State file: state_data/New York
# Number of headers in table: 62
# Number of data in table: 248
# State: North Carolina
# State file: state_data/North Carolina
# Number of headers in table: 100
# Number of data in table: 400
# State: North Dakota
# State file: state_data/North Dakota
# Number of headers in table: 53
# Number of data in table: 212
# State: Ohio
# State file: state_data/Ohio
# Number of headers in table: 88
# Number of data in table: 352
# State: Oklahoma
# State file: state_data/Oklahoma
# Number of headers in table: 77
# Number of data in table: 308
# State: Oregon
# State file: state_data/Oregon
# Number of headers in table: 36
# Number of data in table: 144
# State: Pennsylvania
# State file: state_data/Pennsylvania
# Number of headers in table: 67
# Number of data in table: 268
# State: Rhode Island
# State file: state_data/Rhode Island
# Number of headers in table: 5
# Number of data in table: 20
# State: South Carolina
# State file: state_data/South Carolina
# Number of headers in table: 46
# Number of data in table: 184
# State: South Dakota
# State file: state_data/South Dakota
# Number of headers in table: 66
# Number of data in table: 264
# State: Tennessee
# State file: state_data/Tennessee
# Number of headers in table: 95
# Number of data in table: 380
# State: Texas
# State file: state_data/Texas
# Number of headers in table: 254
# Number of data in table: 1016
# State: Utah
# State file: state_data/Utah
# Number of headers in table: 29
# Number of data in table: 116
# State: Vermont
# State file: state_data/Vermont
# Number of headers in table: 14
# Number of data in table: 56
# State: Virginia
# State file: state_data/Virginia
# Number of headers in table: 133
# Number of data in table: 532
# State: Washington
# State file: state_data/Washington
# Number of headers in table: 39
# Number of data in table: 156
# State: West Virginia
# State file: state_data/West Virginia
# Number of headers in table: 55
# Number of data in table: 220
# State: Wisconsin
# State file: state_data/Wisconsin
# Number of headers in table: 72
# Number of data in table: 288
# State: Wyoming
# State file: state_data/Wyoming
# Number of headers in table: 23
# Number of data in table: 92

# %% [markdown]
# <div class='exercise'><b> Exercise 2.2 [4 pts]: Simple analytics</b>
#
# Complete the `calculate_county_stats()` function, which calculates:
# 1. The single county (and the state to which it belongs) that has the **lowest rate** of COVID cases per 100k people
# 2. The single county (and the state to which it belongs) that has the **highest rate** of COVID cases per 100k people
#
# **NOTES:**
# - Place your resulting variables within the blanks of the `print()` statements that we provide
# - These values you report should be Floating point numbers (e.g., 3.4), not Integers (e.g., 3).
# - If there are ties, return any one of the tied counties (see if you can do it in an unbiased way!)
# </div>

# %%
def calculate_county_stats(covid_data):
    
    # YOUR CODE HERE
    county_index=[]
    county_value_oneperst=[]
    for i in covid_data:
        #print( i)
        temp= []
        for j in covid_data[i]:
            temp.append(covid_data[i][j]['cases']/population_dict[i][j]*(100000))
        max_val= max(temp)
        county_value_oneperst.append(max_val)
        county_index.append(temp.index(max_val))
    
    max_overall_value=max(county_value_oneperst)
    index_want=county_value_oneperst.index(max_overall_value)
    state = list(covid_data.keys())[index_want]
    county = list(covid_data[state].keys())[county_index[index_want]]
    print('County that has the HIGHEST rate of COVID cases per 100k people:', county_index[index_want], county)
    print('State of the aforementioned county:', state_info[index_want][0])
    print('Rate of COVID cases per 100k people in aforementioned county:', max_overall_value)
    
    min_county_index=[]
    min_county_value_oneperst=[]
    for i in covid_data:
        temp= []
        for j in covid_data[i]:
            temp.append(covid_data[i][j]['cases']/population_dict[i][j]*(100000))
        min_val= min(temp)
        min_county_value_oneperst.append(min_val)
        min_county_index.append(temp.index(min_val))
    
    min_overall_value=min(min_county_value_oneperst)
    min_index_want=min_county_value_oneperst.index(min_overall_value)
    min_state = list(covid_data.keys())[min_index_want]
    min_county = list(covid_data[min_state].keys())[min_county_index[min_index_want]]
    print('')
    print('')
    print('County that has the LOWEST rate of COVID cases per 100k people:',min_county_index[min_index_want], min_county)
    print('State of the aforementioned county:',state_info[min_index_want][0])
    print('Rate of COVID cases per 100k people in aforementioned county:', min_overall_value)
    
    return      
    # END OF YOUR CODE HERE

# %% [markdown]
# Run the cell below (no changes necessary) to execute your code above

# %%
calculate_county_stats(covid_data)
# Out:
# County that has the HIGHEST rate of COVID cases per 100k people: 3 Bristol Bay Borough
# State of the aforementioned county: Alaska
# Rate of COVID cases per 100k people in aforementioned county: 72727.27272727274
#
#
# County that has the LOWEST rate of COVID cases per 100k people: 12 Lake and Peninsula Borough
# State of the aforementioned county: Alaska
# Rate of COVID cases per 100k people in aforementioned county: 0.0

# %% [markdown]
# <div class='exercise'><b> Exercise 2.3 [4 pts]: Simple analytics</b>
#
# Complete the `calculate_state_deaths()` function, which calculates:
# 1. The state that has the **lowest number** of deaths
# 2. The state that has the **highest number** of deaths
#
# **NOTES:**
# - Place your resulting variables within the blanks of the `print()` statements that we provide (don't just manually type your textual answers in the blanks)
# - These values you report should be Integers, not Floating point numbers.
# - If there are ties, return any of the tied states
#
# </div>

# %%
def calculate_state_deaths(covid_data):
    
    # YOUR CODE HERE
    county_index=[]
    county_value_oneperst=[]
    lista=[]
    for i in covid_data:
        temp=0
        for j in covid_data[i]:
            temp+=covid_data[i][j]['deaths']
        lista.append(temp)
#    print(len(lista))
            
    ab=max(lista)
    ac=min(lista)
    high=lista.index(ab)
    low=lista.index(ac)
    q=list(covid_data.keys())[high]
    q2=list(covid_data.keys())[low]
    print('This is the state that has the HIGHEST number of deaths:',q)
    print('')
    print('This is the state that has the LOWEST number of deaths:',q2)     
    
    return      
    # END OF YOUR CODE HERE

# %% [markdown]
# Run the cell below (no changes necessary) to execute your code above

# %%
calculate_state_deaths(covid_data)
# Out:
# This is the state that has the HIGHEST number of deaths: California
#
# This is the state that has the LOWEST number of deaths: Hawaii

# %% [markdown]
# <div class='exercise'><b> Exercise 2.4 [4 pts]: Simple analytics</b>
#
# Complete the `calculate_state_deathrate()` function, which calculates:
# 1. The state that has the **lowest rate** of deaths based on its entire population
# 2. The state that has the **highest rate** of deaths based on its entire population
#
# **NOTES:**
# - To calculate a state's population, we are asserting that is sufficient to sum the population over all counties, and that each county's population can be calculated simply from the data fields stored within `covid_data`.
# - **If a county has reported 0 COVID cases,** then we should ignore this county as we estimate its county population. Thus, that county would contribute 0 to its state population total.
# - Round your results to the a single person (e.g., "1 out of every 2703 people has died" not 2703.4)
# - Place your resulting variables within the blanks of the `print()` statements that we provide (don't just manually type your textual answers in the blanks)
# </div>

# %%
def calculate_state_deathrate(covid_data):
    
    # YOUR CODE HERE
    county_index=[]
    county_value_oneperst=[]
    lista=[]

    for i in covid_data:
        temp=0
        temp2=0
        for j in covid_data[i]:
            temp+=covid_data[i][j]['deaths']
            temp2+=population_dict[i][j]
        a = temp/temp2
        lista.append(a)
    #print(len(lista))
    ab=max(lista)
    ac=min(lista)
    high=lista.index(ab)
    low=lista.index(ac)
    #print(high,low)
    q=list(covid_data.keys())[high]
    q2=list(covid_data.keys())[low]
    print('This is the state that has the HIGHEST number of deaths based on its entire population:',q)
    print('')
    print('This is the state that has the LOWEST number of deaths based on its entire population:',q2)     #max_overall_value=max(county_value_oneperst)
    
    return      
    # END OF YOUR CODE HERE

# %% [markdown]
# Run the cell below (no changes necessary) to execute your code above

# %%
calculate_state_deathrate(covid_data)
# Out:
# This is the state that has the HIGHEST number of deaths based on its entire population: Mississippi
#
# This is the state that has the LOWEST number of deaths based on its entire population: Hawaii

# %% [markdown]
# ## 3. PANDAS (36 pts)
# What if we wanted to observe more than just the single-most extreme counties and states? What if we wanted to inspect all states, after having sorted the data by some feature? As you saw in the above exercises, doing the most basic analytics is possible, but it can quickly become cumbersome. As we learned in class, PANDAS is a great library that provides data structures that are highly useful for data analysis.

# %% [markdown]
# <div class='exercise'><b> Exercise 3.1 [10 pts]: Converting to PANDAS</b>
#
# In Exercise 2, we worked with `covid_data`, which is comprises of some combination of lists and/or dictionaries.
#
# Complete the `convert_to_pandas()` function, which converts `covid_data` to a PANDAS DataFrame, whereby:
# - Each row corresponds to a unique county
# - The 4 columns are:
#     - county
#     - state
#     - \# total covid cases (Integer)
#     - \# case per 100k (Integer)
#     - \# covid deaths (Integer)
# - The columns should be titled **exactly** as listed above
#
# **NOTE:**
# - If there exists multiple counties with the same name, each of which belonging to a different state, then there should be a distinct row for each.
# - The 2 columns that correspond to COVID counts should all be Integers (e.g., 1498), not Floating point digits (e.g., 1498.0)
# </div>

# %%
new_df = pd.DataFrame.from_dict({(i,j): covid_data[i][j]
                                 for i in covid_data.keys()
                                 for j in covid_data[i].keys()},
                                orient = 'index')
    
covid_df = new_df.reset_index(inplace = False)
covid_df.rename(columns = {'level_0':'state',
                           'level_1':'county'}, inplace = True)
covid_df
# Out:
#         state             county  seven_d_cases  seven_d_deaths  cases  deaths
# 0     Alabama     Autauga County             41               0   9351     119
# 1     Alabama     Baldwin County            139               4  35221     417
# 2     Alabama     Barbour County             17               0   3329      67
# 3     Alabama        Bibb County             28               0   3859      75
# 4     Alabama      Blount County             42               0   9246     146
# ...       ...                ...            ...             ...    ...     ...
# 3076  Wyoming  Sweetwater County             69               0   6275      51
# 3077  Wyoming       Teton County             25               0   4679      11
# 3078  Wyoming       Uinta County             28               0   3248      16
# 3079  Wyoming    Washakie County             10               0   1148      27
# 3080  Wyoming      Weston County              6               0    845       6
#
# [3081 rows x 6 columns]

# %%
population_dict
# Out:
# {'Alabama': {'Autauga County': 55869,
#   'Baldwin County': 223234,
#   'Barbour County': 24686,
#   'Bibb County': 22394,
#   'Blount County': 57826,
#   'Bullock County': 10101,
#   'Butler County': 19448,
#   'Calhoun County': 113605,
#   'Chambers County': 33254,
#   'Cherokee County': 26196,
#   'Chilton County': 44428,
#   'Choctaw County': 12589,
#   'Clarke County': 23622,
#   'Clay County': 13235,
#   'Cleburne County': 14910,
#   'Coffee County': 52342,
#   'Colbert County': 55241,
#   'Conecuh County': 12067,
#   'Coosa County': 10663,
#   'Covington County': 37049,
#   'Crenshaw County': 13772,
#   'Cullman County': 83768,
#   'Dale County': 49172,
#   'Dallas County': 37196,
#   'DeKalb County': 71513,
#   'Elmore County': 81209,
#   'Escambia County': 36633,
#   'Etowah County': 102268,
#   'Fayette County': 16302,
#   'Franklin County': 31362,
#   'Geneva County': 26271,
#   'Greene County': 8111,
#   'Hale County': 14651,
#   'Henry County': 17205,
#   'Houston County': 105882,
#   'Jackson County': 51626,
#   'Jefferson County': 658573,
#   'Lamar County': 13805,
#   'Lauderdale County': 92729,
#   'Lawrence County': 32924,
#   'Lee County': 164542,
#   'Limestone County': 98915,
#   'Lowndes County': 9726,
#   'Macon County': 18068,
#   'Madison County': 372909,
#   'Marengo County': 18863,
#   'Marion County': 29709,
#   'Marshall County': 96774,
#   'Mobile County': 413210,
#   'Monroe County': 20733,
#   'Montgomery County': 226486,
#   'Morgan County': 119679,
#   'Perry County': 8923,
#   'Pickens County': 19930,
#   'Pike County': 33114,
#   'Randolph County': 22722,
#   'Russell County': 57961,
#   'St. Clair County': 89512,
#   'Shelby County': 217702,
#   'Sumter County': 12427,
#   'Talladega County': 79978,
#   'Tallapoosa County': 40367,
#   'Tuscaloosa County': 209355,
#   'Walker County': 63521,
#   'Washington County': 16326,
#   'Wilcox County': 10373,
#   'Winston County': 23629},
#  'Alaska': {'Aleutians East Borough': 3337,
#   'Aleutians West Census Area': 5634,
#   'Municipality of Anchorage': 288000,
#   'Bethel Census Area': 18386,
#   'Bristol Bay Borough': 836,
#   'Denali Borough': 2097,
#   'Dillingham Census Area': 4916,
#   'Fairbanks North Star Borough': 96849,
#   'Haines Borough': 2530,
#   'Hoonah-Angoon Census Area': 2148,
#   'City and Borough of Juneau': 31974,
#   'Kenai Peninsula Borough': 58708,
#   'Ketchikan Gateway Borough': 13901,
#   'Kodiak Island Borough': 12998,
#   'Kusilvak Census Area': 8314,
#   'Lake and Peninsula Borough': 1592,
#   'Matanuska-Susitna Borough': 108317,
#   'Nome Census Area': 10004,
#   'North Slope Borough': 9832,
#   'Northwest Arctic Borough': 7621,
#   'Petersburg Census Area': 3266,
#   'Prince of Wales-Hyder Census Area': 6203,
#   'Sitka City and Borough': 8493,
#   'Skagway Municipality': 1183,
#   'Southeast Fairbanks Census Area': 6893,
#   'Valdez-Cordova Census Area': 9202,
#   'Wade Hampton Census Area': 0,
#   'Wrangell City and Borough': 2502,
#   'Yakutat City and Borough': 579,
#   'Yukon-Koyukuk Census Area': 5230},
#  'Arizona': {'Apache County': 71887,
#   'Cochise County': 125922,
#   'Coconino County': 143476,
#   'Gila County': 54018,
#   'Graham County': 38837,
#   'Greenlee County': 9498,
#   'La Paz County': 21108,
#   'Maricopa County': 4485414,
#   'Mohave County': 212181,
#   'Navajo County': 110924,
#   'Pima County': 1047279,
#   'Pinal County': 462789,
#   'Santa Cruz County': 46498,
#   'Yavapai County': 235099,
#   'Yuma County': 213787},
#  'Arkansas': {'Arkansas County': 17486,
#   'Ashley County': 19657,
#   'Baxter County': 41932,
#   'Benton County': 279141,
#   'Boone County': 37432,
#   'Bradley County': 10763,
#   'Calhoun County': 5189,
#   'Carroll County': 28380,
#   'Chicot County': 10118,
#   'Clark County': 22320,
#   'Clay County': 14551,
#   'Cleburne County': 24919,
#   'Cleveland County': 7956,
#   'Columbia County': 23457,
#   'Conway County': 20846,
#   'Craighead County': 110332,
#   'Crawford County': 63257,
#   'Crittenden County': 47955,
#   'Cross County': 16419,
#   'Dallas County': 7009,
#   'Desha County': 11361,
#   'Drew County': 18219,
#   'Faulkner County': 126007,
#   'Franklin County': 17715,
#   'Fulton County': 12477,
#   'Garland County': 99386,
#   'Grant County': 18265,
#   'Greene County': 45325,
#   'Hempstead County': 21532,
#   'Hot Spring County': 33771,
#   'Howard County': 13202,
#   'Independence County': 37825,
#   'Izard County': 13629,
#   'Jackson County': 16719,
#   'Jefferson County': 66824,
#   'Johnson County': 26578,
#   'Lafayette County': 6624,
#   'Lawrence County': 16406,
#   'Lee County': 8857,
#   'Lincoln County': 13024,
#   'Little River County': 12259,
#   'Logan County': 21466,
#   'Lonoke County': 73309,
#   'Madison County': 16576,
#   'Marion County': 16694,
#   'Miller County': 43257,
#   'Mississippi County': 40651,
#   'Monroe County': 6701,
#   'Montgomery County': 8986,
#   'Nevada County': 8252,
#   'Newton County': 7753,
#   'Ouachita County': 23382,
#   'Perry County': 10455,
#   'Phillips County': 17782,
#   'Pike County': 10718,
#   'Poinsett County': 23528,
#   'Polk County': 19964,
#   'Pope County': 64072,
#   'Prairie County': 8062,
#   'Pulaski County': 391911,
#   'Randolph County': 17958,
#   'St. Francis County': 24994,
#   'Saline County': 122437,
#   'Scott County': 10281,
#   'Searcy County': 7881,
#   'Sebastian County': 127827,
#   'Sevier County': 17007,
#   'Sharp County': 17442,
#   'Stone County': 12506,
#   'Union County': 38682,
#   'Van Buren County': 16545,
#   'Washington County': 239187,
#   'White County': 78753,
#   'Woodruff County': 6320,
#   'Yell County': 21341},
#  'California': {'Grand Princess Cruise Ship': 0,
#   'Alameda County': 1671329,
#   'Alpine County': 1129,
#   'Amador County': 39752,
#   'Butte County': 219186,
#   'Calaveras County': 45905,
#   'Colusa County': 21547,
#   'Contra Costa County': 1153526,
#   'Del Norte County': 27812,
#   'El Dorado County': 192843,
#   'Fresno County': 999101,
#   'Glenn County': 28393,
#   'Humboldt County': 135558,
#   'Imperial County': 181215,
#   'Inyo County': 18039,
#   'Kern County': 900202,
#   'Kings County': 152940,
#   'Lake County': 64386,
#   'Lassen County': 30573,
#   'Los Angeles County': 10039107,
#   'Madera County': 157327,
#   'Marin County': 258826,
#   'Mariposa County': 17203,
#   'Mendocino County': 86749,
#   'Merced County': 277680,
#   'Modoc County': 8841,
#   'Mono County': 14444,
#   'Monterey County': 434061,
#   'Napa County': 137744,
#   'Nevada County': 99755,
#   'Orange County': 3175692,
#   'Placer County': 398329,
#   'Plumas County': 18807,
#   'Riverside County': 2470546,
#   'Sacramento County': 1552058,
#   'San Benito County': 62808,
#   'San Bernardino County': 2180085,
#   'San Diego County': 3338330,
#   'San Francisco County': 881549,
#   'San Joaquin County': 762148,
#   'San Luis Obispo County': 283111,
#   'San Mateo County': 766573,
#   'Santa Barbara County': 446499,
#   'Santa Clara County': 1927852,
#   'Santa Cruz County': 273213,
#   'Shasta County': 180080,
#   'Sierra County': 3005,
#   'Siskiyou County': 43539,
#   'Solano County': 447643,
#   'Sonoma County': 494336,
#   'Stanislaus County': 550660,
#   'Sutter County': 96971,
#   'Tehama County': 65084,
#   'Trinity County': 12285,
#   'Tulare County': 466195,
#   'Tuolumne County': 54478,
#   'Ventura County': 846006,
#   'Yolo County': 220500,
#   'Yuba County': 78668},
#  'Colorado': {'Adams County': 517421,
#   'Alamosa County': 16233,
#   'Arapahoe County': 656590,
#   'Archuleta County': 14029,
#   'Baca County': 3581,
#   'Bent County': 5577,
#   'Boulder County': 326196,
#   'Broomfield County and City': 70465,
#   'Chaffee County': 20356,
#   'Cheyenne County': 1831,
#   'Clear Creek County': 9700,
#   'Conejos County': 8205,
#   'Costilla County': 3887,
#   'Crowley County': 6061,
#   'Custer County': 5068,
#   'Delta County': 31162,
#   'Denver County': 727211,
#   'Dolores County': 2055,
#   'Douglas County': 351154,
#   'Eagle County': 55127,
#   'Elbert County': 26729,
#   'El Paso County': 720403,
#   'Fremont County': 47839,
#   'Garfield County': 60061,
#   'Gilpin County': 6243,
#   'Grand County': 15734,
#   'Gunnison County': 17462,
#   'Hinsdale County': 820,
#   'Huerfano County': 6897,
#   'Jackson County': 1392,
#   'Jefferson County': 582881,
#   'Kiowa County': 1406,
#   'Kit Carson County': 7097,
#   'Lake County': 8127,
#   'La Plata County': 56221,
#   'Larimer County': 356899,
#   'Las Animas County': 14506,
#   'Lincoln County': 5701,
#   'Logan County': 22409,
#   'Mesa County': 154210,
#   'Mineral County': 769,
#   'Moffat County': 13283,
#   'Montezuma County': 26183,
#   'Montrose County': 42758,
#   'Morgan County': 29068,
#   'Otero County': 18278,
#   'Ouray County': 4952,
#   'Park County': 18845,
#   'Phillips County': 4265,
#   'Pitkin County': 17767,
#   'Prowers County': 12172,
#   'Pueblo County': 168424,
#   'Rio Blanco County': 6324,
#   'Rio Grande County': 11267,
#   'Routt County': 25638,
#   'Saguache County': 6824,
#   'San Juan County': 728,
#   'San Miguel County': 8179,
#   'Sedgwick County': 2248,
#   'Summit County': 31011,
#   'Teller County': 25388,
#   'Washington County': 4908,
#   'Weld County': 324492,
#   'Yuma County': 10019},
#  'Connecticut': {'Fairfield County': 943332,
#   'Hartford County': 891720,
#   'Litchfield County': 180333,
#   'Middlesex County': 162436,
#   'New Haven County': 854757,
#   'New London County': 265206,
#   'Tolland County': 150721,
#   'Windham County': 116782},
#  'Delaware': {'Kent County': 180786,
#   'New Castle County': 558753,
#   'Sussex County': 234225},
#  'District of Columbia': {'District of Columbia': 705749},
#  'Florida': {'Alachua County': 269043,
#   'Baker County': 29210,
#   'Bay County': 174705,
#   'Bradford County': 28201,
#   'Brevard County': 601942,
#   'Broward County': 1952778,
#   'Calhoun County': 14105,
#   'Charlotte County': 188910,
#   'Citrus County': 149657,
#   'Clay County': 219252,
#   'Collier County': 384902,
#   'Columbia County': 71686,
#   'DeSoto County': 38001,
#   'Dixie County': 16826,
#   'Duval County': 957755,
#   'Escambia County': 318316,
#   'Flagler County': 115081,
#   'Franklin County': 12125,
#   'Gadsden County': 45660,
#   'Gilchrist County': 18582,
#   'Glades County': 13811,
#   'Gulf County': 13639,
#   'Hamilton County': 14428,
#   'Hardee County': 26937,
#   'Hendry County': 42022,
#   'Hernando County': 193920,
#   'Highlands County': 106221,
#   'Hillsborough County': 1471968,
#   'Holmes County': 19617,
#   'Indian River County': 159923,
#   'Jackson County': 46414,
#   'Jefferson County': 14246,
#   'Lafayette County': 8422,
#   'Lake County': 367118,
#   'Lee County': 770577,
#   'Leon County': 293582,
#   'Levy County': 41503,
#   'Liberty County': 8354,
#   'Madison County': 18493,
#   'Manatee County': 403253,
#   'Marion County': 365579,
#   'Martin County': 161000,
#   'Miami-Dade County': 2716940,
#   'Monroe County': 74228,
#   'Nassau County': 88625,
#   'Okaloosa County': 210738,
#   'Okeechobee County': 42168,
#   'Orange County': 1393452,
#   'Osceola County': 375751,
#   'Palm Beach County': 1496770,
#   'Pasco County': 553947,
#   'Pinellas County': 974996,
#   'Polk County': 724777,
#   'Putnam County': 74521,
#   'St. Johns County': 264672,
#   'St. Lucie County': 328297,
#   'Santa Rosa County': 184313,
#   'Sarasota County': 433742,
#   'Seminole County': 471826,
#   'Sumter County': 132420,
#   'Suwannee County': 44417,
#   'Taylor County': 21569,
#   'Union County': 15237,
#   'Volusia County': 553284,
#   'Wakulla County': 33739,
#   'Walton County': 74071,
#   'Washington County': 25473},
#  'Georgia': {'Appling County': 18386,
#   'Atkinson County': 8165,
#   'Bacon County': 11164,
#   'Baker County': 3038,
#   'Baldwin County': 44890,
#   'Banks County': 19234,
#   'Barrow County': 83240,
#   'Bartow County': 107738,
#   'Ben Hill County': 16700,
#   'Berrien County': 19397,
#   'Bibb County': 153159,
#   'Bleckley County': 12873,
#   'Brantley County': 19109,
#   'Brooks County': 15457,
#   'Bryan County': 39627,
#   'Bulloch County': 79608,
#   'Burke County': 22383,
#   'Butts County': 24936,
#   'Calhoun County': 6189,
#   'Camden County': 54666,
#   'Candler County': 10803,
#   'Carroll County': 119992,
#   'Catoosa County': 67580,
#   'Charlton County': 13392,
#   'Chatham County': 289430,
#   'Chattahoochee County': 10907,
#   'Chattooga County': 24789,
#   'Cherokee County': 258773,
#   'Clarke County': 128331,
#   'Clay County': 2834,
#   'Clayton County': 292256,
#   'Clinch County': 6618,
#   'Cobb County': 760141,
#   'Coffee County': 43273,
#   'Colquitt County': 45600,
#   'Columbia County': 156714,
#   'Cook County': 17270,
#   'Coweta County': 148509,
#   'Crawford County': 12404,
#   'Crisp County': 22372,
#   'Dade County': 16116,
#   'Dawson County': 26108,
#   'Decatur County': 26404,
#   'DeKalb County': 759297,
#   'Dodge County': 20605,
#   'Dooly County': 13390,
#   'Dougherty County': 87956,
#   'Douglas County': 146343,
#   'Early County': 10190,
#   'Echols County': 4006,
#   'Effingham County': 64296,
#   'Elbert County': 19194,
#   'Emanuel County': 22646,
#   'Evans County': 10654,
#   'Fannin County': 26188,
#   'Fayette County': 114421,
#   'Floyd County': 98498,
#   'Forsyth County': 244252,
#   'Franklin County': 23349,
#   'Fulton County': 1063937,
#   'Gilmer County': 31369,
#   'Glascock County': 2971,
#   'Glynn County': 85292,
#   'Gordon County': 57963,
#   'Grady County': 24633,
#   'Greene County': 18324,
#   'Gwinnett County': 936250,
#   'Habersham County': 45328,
#   'Hall County': 204441,
#   'Hancock County': 8457,
#   'Haralson County': 29792,
#   'Harris County': 35236,
#   'Hart County': 26205,
#   'Heard County': 11923,
#   'Henry County': 234561,
#   'Houston County': 157863,
#   'Irwin County': 9416,
#   'Jackson County': 72977,
#   'Jasper County': 14219,
#   'Jeff Davis County': 15115,
#   'Jefferson County': 15362,
#   'Jenkins County': 8676,
#   'Johnson County': 9643,
#   'Jones County': 28735,
#   'Lamar County': 19077,
#   'Lanier County': 10423,
#   'Laurens County': 47546,
#   'Lee County': 29992,
#   'Liberty County': 61435,
#   'Lincoln County': 7921,
#   'Long County': 19559,
#   'Lowndes County': 117406,
#   'Lumpkin County': 33610,
#   'McDuffie County': 21312,
#   'McIntosh County': 14378,
#   'Macon County': 12947,
#   'Madison County': 29880,
#   'Marion County': 8359,
#   'Meriwether County': 21167,
#   'Miller County': 5718,
#   'Mitchell County': 21863,
#   'Monroe County': 27578,
#   'Montgomery County': 9172,
#   'Morgan County': 19276,
#   'Murray County': 40096,
#   'Muscogee County': 195769,
#   'Newton County': 111744,
#   'Oconee County': 40280,
#   'Oglethorpe County': 15259,
#   'Paulding County': 168667,
#   'Peach County': 27546,
#   'Pickens County': 32591,
#   'Pierce County': 19465,
#   'Pike County': 18962,
#   'Polk County': 42613,
#   'Pulaski County': 11137,
#   'Putnam County': 22119,
#   'Quitman County': 2299,
#   'Rabun County': 17137,
#   'Randolph County': 6778,
#   'Richmond County': 202518,
#   'Rockdale County': 90896,
#   'Schley County': 5257,
#   'Screven County': 13966,
#   'Seminole County': 8090,
#   'Spalding County': 66703,
#   'Stephens County': 25925,
#   'Stewart County': 6621,
#   'Sumter County': 29524,
#   'Talbot County': 6195,
#   'Taliaferro County': 1537,
#   'Tattnall County': 25286,
#   'Taylor County': 8020,
#   'Telfair County': 15860,
#   'Terrell County': 8531,
#   'Thomas County': 44451,
#   'Tift County': 40644,
#   'Toombs County': 26830,
#   'Towns County': 12037,
#   'Treutlen County': 6901,
#   'Troup County': 69922,
#   'Turner County': 7985,
#   'Twiggs County': 8120,
#   'Union County': 24511,
#   'Upson County': 26320,
#   'Walker County': 69761,
#   'Walton County': 94593,
#   'Ware County': 35734,
#   'Warren County': 5254,
#   'Washington County': 20374,
#   'Wayne County': 29927,
#   'Webster County': 2607,
#   'Wheeler County': 7855,
#   'White County': 30798,
#   'Whitfield County': 104628,
#   'Wilcox County': 8635,
#   'Wilkes County': 9777,
#   'Wilkinson County': 8954,
#   'Worth County': 20247},
#  'Hawaii': {'Hawaii County': 201513,
#   'Honolulu County': 974563,
#   'Kalawao County': 86,
#   'Kauai County': 72293,
#   'Maui County': 167417},
#  'Idaho': {'Ada County': 481587,
#   'Adams County': 4294,
#   'Bannock County': 87808,
#   'Bear Lake County': 6125,
#   'Benewah County': 9298,
#   'Bingham County': 46811,
#   'Blaine County': 23021,
#   'Boise County': 7831,
#   'Bonner County': 45739,
#   'Bonneville County': 119062,
#   'Boundary County': 12245,
#   'Butte County': 2597,
#   'Camas County': 1106,
#   'Canyon County': 229849,
#   'Caribou County': 7155,
#   'Cassia County': 24030,
#   'Clark County': 845,
#   'Clearwater County': 8756,
#   'Custer County': 4315,
#   'Elmore County': 27511,
#   'Franklin County': 13876,
#   'Fremont County': 13099,
#   'Gem County': 18112,
#   'Gooding County': 15179,
#   'Idaho County': 16667,
#   'Jefferson County': 29871,
#   'Jerome County': 24412,
#   'Kootenai County': 165697,
#   'Latah County': 40108,
#   'Lemhi County': 8027,
#   'Lewis County': 3838,
#   'Lincoln County': 5366,
#   'Madison County': 39907,
#   'Minidoka County': 21039,
#   'Nez Perce County': 40408,
#   'Oneida County': 4531,
#   'Owyhee County': 11823,
#   'Payette County': 23951,
#   'Power County': 7681,
#   'Shoshone County': 12882,
#   'Teton County': 12142,
#   'Twin Falls County': 86878,
#   'Valley County': 11392,
#   'Washington County': 10194},
#  'Illinois': {'Adams County': 65435,
#   'Alexander County': 5761,
#   'Bond County': 16426,
#   'Boone County': 53544,
#   'Brown County': 6578,
#   'Bureau County': 32628,
#   'Calhoun County': 4739,
#   'Carroll County': 14305,
#   'Cass County': 12147,
#   'Champaign County': 209689,
#   'Christian County': 32304,
#   'Clark County': 15441,
#   'Clay County': 13184,
#   'Clinton County': 37562,
#   'Coles County': 50621,
#   'Cook County': 5150233,
#   'Crawford County': 18667,
#   'Cumberland County': 10766,
#   'DeKalb County': 104897,
#   'De Witt County': 15638,
#   'Douglas County': 19465,
#   'DuPage County': 922921,
#   'Edgar County': 17161,
#   'Edwards County': 6395,
#   'Effingham County': 34008,
#   'Fayette County': 21336,
#   'Ford County': 12961,
#   'Franklin County': 38469,
#   'Fulton County': 34340,
#   'Gallatin County': 4828,
#   'Greene County': 12969,
#   'Grundy County': 51054,
#   'Hamilton County': 8116,
#   'Hancock County': 17708,
#   'Hardin County': 3821,
#   'Henderson County': 6646,
#   'Henry County': 48913,
#   'Iroquois County': 27114,
#   'Jackson County': 56750,
#   'Jasper County': 9610,
#   'Jefferson County': 37684,
#   'Jersey County': 21773,
#   'Jo Daviess County': 21235,
#   'Johnson County': 12417,
#   'Kane County': 532403,
#   'Kankakee County': 109862,
#   'Kendall County': 128990,
#   'Knox County': 49699,
#   'Lake County': 696535,
#   'LaSalle County': 108669,
#   'Lawrence County': 15678,
#   'Lee County': 34096,
#   'Livingston County': 35648,
#   'Logan County': 28618,
#   'McDonough County': 29682,
#   'McHenry County': 307774,
#   'McLean County': 171517,
#   'Macon County': 104009,
#   'Macoupin County': 44926,
#   'Madison County': 262966,
#   'Marion County': 37205,
#   'Marshall County': 11438,
#   'Mason County': 13359,
#   'Massac County': 13772,
#   'Menard County': 12196,
#   'Mercer County': 15437,
#   'Monroe County': 34637,
#   'Montgomery County': 28414,
#   'Morgan County': 33658,
#   'Moultrie County': 14501,
#   'Ogle County': 50643,
#   'Peoria County': 179179,
#   'Perry County': 20916,
#   'Piatt County': 16344,
#   'Pike County': 15561,
#   'Pope County': 4177,
#   'Pulaski County': 5335,
#   'Putnam County': 5739,
#   'Randolph County': 31782,
#   'Richland County': 15513,
#   'Rock Island County': 141879,
#   'St. Clair County': 259686,
#   'Saline County': 23491,
#   'Sangamon County': 194672,
#   'Schuyler County': 6768,
#   'Scott County': 4951,
#   'Shelby County': 21634,
#   'Stark County': 5342,
#   'Stephenson County': 44498,
#   'Tazewell County': 131803,
#   'Union County': 16653,
#   'Vermilion County': 75758,
#   'Wabash County': 11520,
#   'Warren County': 16844,
#   'Washington County': 13887,
#   'Wayne County': 16215,
#   'White County': 13537,
#   'Whiteside County': 55175,
#   'Will County': 690743,
#   'Williamson County': 66597,
#   'Winnebago County': 282572,
#   'Woodford County': 38459},
#  'Indiana': {'Adams County': 35777,
#   'Allen County': 379299,
#   'Bartholomew County': 83779,
#   'Benton County': 8748,
#   'Blackford County': 11758,
#   'Boone County': 67843,
#   'Brown County': 15092,
#   'Carroll County': 20257,
#   'Cass County': 37689,
#   'Clark County': 118302,
#   'Clay County': 26225,
#   'Clinton County': 32399,
#   'Crawford County': 10577,
#   'Daviess County': 33351,
#   'Dearborn County': 49458,
#   'Decatur County': 26559,
#   'DeKalb County': 43475,
#   'Delaware County': 114135,
#   'Dubois County': 42736,
#   'Elkhart County': 206341,
#   'Fayette County': 23102,
#   'Floyd County': 78522,
#   'Fountain County': 16346,
#   'Franklin County': 22758,
#   'Fulton County': 19974,
#   'Gibson County': 33659,
#   'Grant County': 65769,
#   'Greene County': 31922,
#   'Hamilton County': 338011,
#   'Hancock County': 78168,
#   'Harrison County': 40515,
#   'Hendricks County': 170311,
#   'Henry County': 47972,
#   'Howard County': 82544,
#   'Huntington County': 36520,
#   'Jackson County': 44231,
#   'Jasper County': 33562,
#   'Jay County': 20436,
#   'Jefferson County': 32308,
#   'Jennings County': 27735,
#   'Johnson County': 158167,
#   'Knox County': 36594,
#   'Kosciusko County': 79456,
#   'LaGrange County': 39614,
#   'Lake County': 485493,
#   'LaPorte County': 109888,
#   'Lawrence County': 45370,
#   'Madison County': 129569,
#   'Marion County': 964582,
#   'Marshall County': 46258,
#   'Martin County': 10255,
#   'Miami County': 35516,
#   'Monroe County': 148431,
#   'Montgomery County': 38338,
#   'Morgan County': 70489,
#   'Newton County': 13984,
#   'Noble County': 47744,
#   'Ohio County': 5875,
#   'Orange County': 19646,
#   'Owen County': 20799,
#   'Parke County': 16937,
#   'Perry County': 19169,
#   'Pike County': 12389,
#   'Porter County': 170389,
#   'Posey County': 25427,
#   'Pulaski County': 12353,
#   'Putnam County': 37576,
#   'Randolph County': 24665,
#   'Ripley County': 28324,
#   'Rush County': 16581,
#   'St. Joseph County': 271826,
#   'Scott County': 23873,
#   'Shelby County': 44729,
#   'Spencer County': 20277,
#   'Starke County': 22995,
#   'Steuben County': 34594,
#   'Sullivan County': 20669,
#   'Switzerland County': 10751,
#   'Tippecanoe County': 195732,
#   'Tipton County': 15148,
#   'Union County': 7054,
#   'Vanderburgh County': 181451,
#   'Vermillion County': 15498,
#   'Vigo County': 107038,
#   'Wabash County': 30996,
#   'Warren County': 8265,
#   'Warrick County': 62998,
#   'Washington County': 28036,
#   'Wayne County': 65884,
#   'Wells County': 28296,
#   'White County': 24102,
#   'Whitley County': 33964},
#  'Iowa': {'Adair County': 7152,
#   'Adams County': 3602,
#   'Allamakee County': 13687,
#   'Appanoose County': 12426,
#   'Audubon County': 5496,
#   'Benton County': 25645,
#   'Black Hawk County': 131228,
#   'Boone County': 26234,
#   'Bremer County': 25062,
#   'Buchanan County': 21175,
#   'Buena Vista County': 19620,
#   'Butler County': 14439,
#   'Calhoun County': 9668,
#   'Carroll County': 20165,
#   'Cass County': 12836,
#   'Cedar County': 18627,
#   'Cerro Gordo County': 42450,
#   'Cherokee County': 11235,
#   'Chickasaw County': 11933,
#   'Clarke County': 9395,
#   'Clay County': 16016,
#   'Clayton County': 17549,
#   'Clinton County': 46429,
#   'Crawford County': 16820,
#   'Dallas County': 93453,
#   'Davis County': 9000,
#   'Decatur County': 7870,
#   'Delaware County': 17011,
#   'Des Moines County': 38967,
#   'Dickinson County': 17258,
#   'Dubuque County': 97311,
#   'Emmet County': 9208,
#   'Fayette County': 19650,
#   'Floyd County': 15642,
#   'Franklin County': 10070,
#   'Fremont County': 6960,
#   'Greene County': 8888,
#   'Grundy County': 12232,
#   'Guthrie County': 10689,
#   'Hamilton County': 14773,
#   'Hancock County': 10630,
#   'Hardin County': 16846,
#   'Harrison County': 14049,
#   'Henry County': 19954,
#   'Howard County': 9158,
#   'Humboldt County': 9558,
#   'Ida County': 6860,
#   'Iowa County': 16184,
#   'Jackson County': 19439,
#   'Jasper County': 37185,
#   'Jefferson County': 18295,
#   'Johnson County': 151140,
#   'Jones County': 20681,
#   'Keokuk County': 10246,
#   'Kossuth County': 14813,
#   'Lee County': 33657,
#   'Linn County': 226706,
#   'Louisa County': 11035,
#   'Lucas County': 8600,
#   'Lyon County': 11755,
#   'Madison County': 16338,
#   'Mahaska County': 22095,
#   'Marion County': 33253,
#   'Marshall County': 39369,
#   'Mills County': 15109,
#   'Mitchell County': 10586,
#   'Monona County': 8615,
#   'Monroe County': 7707,
#   'Montgomery County': 9917,
#   'Muscatine County': 42664,
#   "O'Brien County": 13753,
#   'Osceola County': 5958,
#   'Page County': 15107,
#   'Palo Alto County': 8886,
#   'Plymouth County': 25177,
#   'Pocahontas County': 6619,
#   'Polk County': 490161,
#   'Pottawattamie County': 93206,
#   'Poweshiek County': 18504,
#   'Ringgold County': 4894,
#   'Sac County': 9721,
#   'Scott County': 172943,
#   'Shelby County': 11454,
#   'Sioux County': 34855,
#   'Story County': 97117,
#   'Tama County': 16854,
#   'Taylor County': 6121,
#   'Union County': 12241,
#   'Van Buren County': 7044,
#   'Wapello County': 34969,
#   'Warren County': 51466,
#   'Washington County': 21965,
#   'Wayne County': 6441,
#   'Webster County': 35904,
#   'Winnebago County': 10354,
#   'Winneshiek County': 19991,
#   'Woodbury County': 103107,
#   'Worth County': 7381,
#   'Wright County': 12562},
#  'Kansas': {'Allen County': 12369,
#   'Anderson County': 7858,
#   'Atchison County': 16073,
#   'Barber County': 4427,
#   'Barton County': 25779,
#   'Bourbon County': 14534,
#   'Brown County': 9564,
#   'Butler County': 66911,
#   'Chase County': 2648,
#   'Chautauqua County': 3250,
#   'Cherokee County': 19939,
#   'Cheyenne County': 2657,
#   'Clark County': 1994,
#   'Clay County': 8002,
#   'Cloud County': 8786,
#   'Coffey County': 8179,
#   'Comanche County': 1700,
#   'Cowley County': 34908,
#   'Crawford County': 38818,
#   'Decatur County': 2827,
#   'Dickinson County': 18466,
#   'Doniphan County': 7600,
#   'Douglas County': 122259,
#   'Edwards County': 2798,
#   'Elk County': 2530,
#   'Ellis County': 28553,
#   'Ellsworth County': 6102,
#   'Finney County': 36467,
#   'Ford County': 33619,
#   'Franklin County': 25544,
#   'Geary County': 31670,
#   'Gove County': 2636,
#   'Graham County': 2482,
#   'Grant County': 7150,
#   'Gray County': 5988,
#   'Greeley County': 1232,
#   'Greenwood County': 5982,
#   'Hamilton County': 2539,
#   'Harper County': 5436,
#   'Harvey County': 34429,
#   'Haskell County': 3968,
#   'Hodgeman County': 1794,
#   'Jackson County': 13171,
#   'Jefferson County': 19043,
#   'Jewell County': 2879,
#   'Johnson County': 602401,
#   'Kearny County': 3838,
#   'Kingman County': 7152,
#   'Kiowa County': 2475,
#   'Labette County': 19618,
#   'Lane County': 1535,
#   'Leavenworth County': 81758,
#   'Lincoln County': 2962,
#   'Linn County': 9703,
#   'Logan County': 2794,
#   'Lyon County': 33195,
#   'McPherson County': 28542,
#   'Marion County': 11884,
#   'Marshall County': 9707,
#   'Meade County': 4033,
#   'Miami County': 34237,
#   'Mitchell County': 5979,
#   'Montgomery County': 31829,
#   'Morris County': 5620,
#   'Morton County': 2587,
#   'Nemaha County': 10231,
#   'Neosho County': 16007,
#   'Ness County': 2750,
#   'Norton County': 5361,
#   'Osage County': 15949,
#   'Osborne County': 3421,
#   'Ottawa County': 5704,
#   'Pawnee County': 6414,
#   'Phillips County': 5234,
#   'Pottawatomie County': 24383,
#   'Pratt County': 9164,
#   'Rawlins County': 2530,
#   'Reno County': 61998,
#   'Republic County': 4636,
#   'Rice County': 9537,
#   'Riley County': 74232,
#   'Rooks County': 4920,
#   'Rush County': 3036,
#   'Russell County': 6856,
#   'Saline County': 54224,
#   'Scott County': 4823,
#   'Sedgwick County': 516042,
#   'Seward County': 21428,
#   'Shawnee County': 176875,
#   'Sheridan County': 2521,
#   'Sherman County': 5917,
#   'Smith County': 3583,
#   'Stafford County': 4156,
#   'Stanton County': 2006,
#   'Stevens County': 5485,
#   'Sumner County': 22836,
#   'Thomas County': 7777,
#   'Trego County': 2803,
#   'Wabaunsee County': 6931,
#   'Wallace County': 1518,
#   'Washington County': 5406,
#   'Wichita County': 2119,
#   'Wilson County': 8525,
#   'Woodson County': 3138,
#   'Wyandotte County': 165429},
#  'Kentucky': {'Adair County': 19202,
#   'Allen County': 21315,
#   'Anderson County': 22747,
#   'Ballard County': 7888,
#   'Barren County': 44249,
#   'Bath County': 12500,
#   'Bell County': 26032,
#   'Boone County': 133581,
#   'Bourbon County': 19788,
#   'Boyd County': 46718,
#   'Boyle County': 30060,
#   'Bracken County': 8303,
#   'Breathitt County': 12630,
#   'Breckinridge County': 20477,
#   'Bullitt County': 81676,
#   'Butler County': 12879,
#   'Caldwell County': 12747,
#   'Calloway County': 39001,
#   'Campbell County': 93584,
#   'Carlisle County': 4760,
#   'Carroll County': 10631,
#   'Carter County': 26797,
#   'Casey County': 16159,
#   'Christian County': 70461,
#   'Clark County': 36263,
#   'Clay County': 19901,
#   'Clinton County': 10218,
#   'Crittenden County': 8806,
#   'Cumberland County': 6614,
#   'Daviess County': 101511,
#   'Edmonson County': 12150,
#   'Elliott County': 7517,
#   'Estill County': 14106,
#   'Fayette County': 323152,
#   'Fleming County': 14581,
#   'Floyd County': 35589,
#   'Franklin County': 50991,
#   'Fulton County': 5969,
#   'Gallatin County': 8869,
#   'Garrard County': 17666,
#   'Grant County': 25069,
#   'Graves County': 37266,
#   'Grayson County': 26427,
#   'Green County': 10941,
#   'Greenup County': 35098,
#   'Hancock County': 8722,
#   'Hardin County': 110958,
#   'Harlan County': 26010,
#   'Harrison County': 18886,
#   'Hart County': 19035,
#   'Henderson County': 45210,
#   'Henry County': 16126,
#   'Hickman County': 4380,
#   'Hopkins County': 44686,
#   'Jackson County': 13329,
#   'Jefferson County': 766757,
#   'Jessamine County': 54115,
#   'Johnson County': 22188,
#   'Kenton County': 166998,
#   'Knott County': 14806,
#   'Knox County': 31145,
#   'Larue County': 14398,
#   'Laurel County': 60813,
#   'Lawrence County': 15317,
#   'Lee County': 7403,
#   'Leslie County': 9877,
#   'Letcher County': 21553,
#   'Lewis County': 13275,
#   'Lincoln County': 24549,
#   'Livingston County': 9194,
#   'Logan County': 27102,
#   'Lyon County': 8210,
#   'McCracken County': 65418,
#   'McCreary County': 17231,
#   'McLean County': 9207,
#   'Madison County': 92987,
#   'Magoffin County': 12161,
#   'Marion County': 19273,
#   'Marshall County': 31100,
#   'Martin County': 11195,
#   'Mason County': 17070,
#   'Meade County': 28572,
#   'Menifee County': 6489,
#   'Mercer County': 21933,
#   'Metcalfe County': 10071,
#   'Monroe County': 10650,
#   'Montgomery County': 28157,
#   'Morgan County': 13309,
#   'Muhlenberg County': 30622,
#   'Nelson County': 46233,
#   'Nicholas County': 7269,
#   'Ohio County': 23994,
#   'Oldham County': 66799,
#   'Owen County': 10901,
#   'Owsley County': 4415,
#   'Pendleton County': 14590,
#   'Perry County': 25758,
#   'Pike County': 57876,
#   'Powell County': 12359,
#   'Pulaski County': 64979,
#   'Robertson County': 2108,
#   'Rockcastle County': 16695,
#   'Rowan County': 24460,
#   'Russell County': 17923,
#   'Scott County': 57004,
#   'Shelby County': 49024,
#   'Simpson County': 18572,
#   'Spencer County': 19351,
#   'Taylor County': 25769,
#   'Todd County': 12294,
#   'Trigg County': 14651,
#   'Trimble County': 8471,
#   'Union County': 14381,
#   'Warren County': 132896,
#   'Washington County': 12095,
#   'Wayne County': 20333,
#   'Webster County': 12942,
#   'Whitley County': 36264,
#   'Wolfe County': 7157,
#   'Woodford County': 26734},
#  'Louisiana': {'Acadia Parish': 62045,
#   'Allen Parish': 25627,
#   'Ascension Parish': 126604,
#   'Assumption Parish': 21891,
#   'Avoyelles Parish': 40144,
#   'Beauregard Parish': 37497,
#   'Bienville Parish': 13241,
#   'Bossier Parish': 127039,
#   'Caddo Parish': 240204,
#   'Calcasieu Parish': 203436,
#   'Caldwell Parish': 9918,
#   'Cameron Parish': 6973,
#   'Catahoula Parish': 9494,
#   'Claiborne Parish': 15670,
#   'Concordia Parish': 19259,
#   'De Soto Parish': 27463,
#   'East Baton Rouge Parish': 440059,
#   'East Carroll Parish': 6861,
#   'East Feliciana Parish': 19135,
#   'Evangeline Parish': 33395,
#   'Franklin Parish': 20015,
#   'Grant Parish': 22389,
#   'Iberia Parish': 69830,
#   'Iberville Parish': 32511,
#   'Jackson Parish': 15744,
#   'Jefferson Parish': 432493,
#   'Jefferson Davis Parish': 31368,
#   'Lafayette Parish': 244390,
#   'Lafourche Parish': 97614,
#   'La Salle Parish': 14892,
#   'Lincoln Parish': 46742,
#   'Livingston Parish': 140789,
#   'Madison Parish': 10951,
#   'Morehouse Parish': 24874,
#   'Natchitoches Parish': 38158,
#   'Orleans Parish': 390144,
#   'Ouachita Parish': 153279,
#   'Plaquemines Parish': 23197,
#   'Pointe Coupee Parish': 21730,
#   'Rapides Parish': 129648,
#   'Red River Parish': 8442,
#   'Richland Parish': 20122,
#   'Sabine Parish': 23884,
#   'St. Bernard Parish': 47244,
#   'St. Charles Parish': 53100,
#   'St. Helena Parish': 10132,
#   'St. James Parish': 21096,
#   'St. John the Baptist Parish': 42837,
#   'St. Landry Parish': 82124,
#   'St. Martin Parish': 53431,
#   'St. Mary Parish': 49348,
#   'St. Tammany Parish': 260419,
#   'Tangipahoa Parish': 134758,
#   'Tensas Parish': 4334,
#   'Terrebonne Parish': 110461,
#   'Union Parish': 22108,
#   'Vermilion Parish': 59511,
#   'Vernon Parish': 47429,
#   'Washington Parish': 46194,
#   'Webster Parish': 38340,
#   'West Baton Rouge Parish': 26465,
#   'West Carroll Parish': 10830,
#   'West Feliciana Parish': 15568,
#   'Winn Parish': 13904},
#  'Maine': {'Androscoggin County': 108277,
#   'Aroostook County': 67055,
#   'Cumberland County': 295003,
#   'Franklin County': 30199,
#   'Hancock County': 54987,
#   'Kennebec County': 122302,
#   'Knox County': 39772,
#   'Lincoln County': 34634,
#   'Oxford County': 57975,
#   'Penobscot County': 152148,
#   'Piscataquis County': 16785,
#   'Sagadahoc County': 35856,
#   'Somerset County': 50484,
#   'Waldo County': 39715,
#   'Washington County': 31379,
#   'York County': 207641},
#  'Maryland': {'Allegany County': 70416,
#   'Anne Arundel County': 579234,
#   'Baltimore County': 827370,
#   'Calvert County': 92525,
#   'Caroline County': 33406,
#   'Carroll County': 168447,
#   'Cecil County': 102855,
#   'Charles County': 163257,
#   'Dorchester County': 31929,
#   'Frederick County': 259547,
#   'Garrett County': 29014,
#   'Harford County': 255441,
#   'Howard County': 325690,
#   'Kent County': 19422,
#   'Montgomery County': 1050688,
#   "Prince George's County": 909327,
#   "Queen Anne's County": 50381,
#   "St. Mary's County": 113510,
#   'Somerset County': 25616,
#   'Talbot County': 37181,
#   'Washington County': 151049,
#   'Wicomico County': 103609,
#   'Worcester County': 52276,
#   'Baltimore City': 593490},
#  'Massachusetts': {'Barnstable County': 212990,
#   'Berkshire County': 124944,
#   'Bristol County': 565217,
#   'Dukes County': 17332,
#   'Essex County': 789034,
#   'Franklin County': 70180,
#   'Hampden County': 466372,
#   'Hampshire County': 160830,
#   'Middlesex County': 1611699,
#   'Nantucket County': 11399,
#   'Norfolk County': 706775,
#   'Plymouth County': 521202,
#   'Suffolk County': 803907,
#   'Worcester County': 830622},
#  'Michigan': {'Alcona County': 10405,
#   'Alger County': 9108,
#   'Allegan County': 118081,
#   'Alpena County': 28405,
#   'Antrim County': 23324,
#   'Arenac County': 14883,
#   'Baraga County': 8209,
#   'Barry County': 61550,
#   'Bay County': 103126,
#   'Benzie County': 17766,
#   'Berrien County': 153401,
#   'Branch County': 43517,
#   'Calhoun County': 134159,
#   'Cass County': 51787,
#   'Charlevoix County': 26143,
#   'Cheboygan County': 25276,
#   'Chippewa County': 37349,
#   'Clare County': 30950,
#   'Clinton County': 79595,
#   'Crawford County': 14029,
#   'Delta County': 35784,
#   'Dickinson County': 25239,
#   'Eaton County': 110268,
#   'Emmet County': 33415,
#   'Genesee County': 405813,
#   'Gladwin County': 25449,
#   'Gogebic County': 13975,
#   'Grand Traverse County': 93088,
#   'Gratiot County': 40711,
#   'Hillsdale County': 45605,
#   'Houghton County': 35684,
#   'Huron County': 30981,
#   'Ingham County': 292406,
#   'Ionia County': 64697,
#   'Iosco County': 25127,
#   'Iron County': 11066,
#   'Isabella County': 69872,
#   'Jackson County': 158510,
#   'Kalamazoo County': 265066,
#   'Kalkaska County': 18038,
#   'Kent County': 656955,
#   'Keweenaw County': 2116,
#   'Lake County': 11853,
#   'Lapeer County': 87607,
#   'Leelanau County': 21761,
#   'Lenawee County': 98451,
#   'Livingston County': 191995,
#   'Luce County': 6229,
#   'Mackinac County': 10799,
#   'Macomb County': 873972,
#   'Manistee County': 24558,
#   'Marquette County': 66699,
#   'Mason County': 29144,
#   'Mecosta County': 43453,
#   'Menominee County': 22780,
#   'Midland County': 83156,
#   'Missaukee County': 15118,
#   'Monroe County': 150500,
#   'Montcalm County': 63888,
#   'Montmorency County': 9328,
#   'Muskegon County': 173566,
#   'Newaygo County': 48980,
#   'Oakland County': 1257584,
#   'Oceana County': 26467,
#   'Ogemaw County': 20997,
#   'Ontonagon County': 5720,
#   'Osceola County': 23460,
#   'Oscoda County': 8241,
#   'Otsego County': 24668,
#   'Ottawa County': 291830,
#   'Presque Isle County': 12592,
#   'Roscommon County': 24019,
#   'Saginaw County': 190539,
#   'St. Clair County': 159128,
#   'St. Joseph County': 60964,
#   'Sanilac County': 41170,
#   'Schoolcraft County': 8094,
#   'Shiawassee County': 68122,
#   'Tuscola County': 52245,
#   'Van Buren County': 75677,
#   'Washtenaw County': 367601,
#   'Wayne County': 1749343,
#   'Wexford County': 33631},
#  'Minnesota': {'Aitkin County': 15886,
#   'Anoka County': 356921,
#   'Becker County': 34423,
#   'Beltrami County': 47188,
#   'Benton County': 40889,
#   'Big Stone County': 4991,
#   'Blue Earth County': 67653,
#   'Brown County': 25008,
#   'Carlton County': 35871,
#   'Carver County': 105089,
#   'Cass County': 29779,
#   'Chippewa County': 11800,
#   'Chisago County': 56579,
#   'Clay County': 64222,
#   'Clearwater County': 8818,
#   'Cook County': 5463,
#   'Cottonwood County': 11196,
#   'Crow Wing County': 65055,
#   'Dakota County': 429021,
#   'Dodge County': 20934,
#   'Douglas County': 38141,
#   'Faribault County': 13653,
#   'Fillmore County': 21067,
#   'Freeborn County': 30281,
#   'Goodhue County': 46340,
#   'Grant County': 5972,
#   'Hennepin County': 1265843,
#   'Houston County': 18600,
#   'Hubbard County': 21491,
#   'Isanti County': 40596,
#   'Itasca County': 45130,
#   'Jackson County': 9846,
#   'Kanabec County': 16337,
#   'Kandiyohi County': 43199,
#   'Kittson County': 4298,
#   'Koochiching County': 12229,
#   'Lac Qui Parle County': 6623,
#   'Lake County': 10641,
#   'Lake of the Woods County': 3740,
#   'Le Sueur County': 28887,
#   'Lincoln County': 5639,
#   'Lyon County': 25474,
#   'McLeod County': 35893,
#   'Mahnomen County': 5527,
#   'Marshall County': 9336,
#   'Martin County': 19683,
#   'Meeker County': 23222,
#   'Mille Lacs County': 26277,
#   'Morrison County': 33386,
#   'Mower County': 40062,
#   'Murray County': 8194,
#   'Nicollet County': 34274,
#   'Nobles County': 21629,
#   'Norman County': 6375,
#   'Olmsted County': 158293,
#   'Otter Tail County': 58746,
#   'Pennington County': 14119,
#   'Pine County': 29579,
#   'Pipestone County': 9126,
#   'Polk County': 31364,
#   'Pope County': 11249,
#   'Ramsey County': 550321,
#   'Red Lake County': 4055,
#   'Redwood County': 15170,
#   'Renville County': 14548,
#   'Rice County': 66972,
#   'Rock County': 9315,
#   'Roseau County': 15165,
#   'St. Louis County': 199070,
#   'Scott County': 149013,
#   'Sherburne County': 97238,
#   'Sibley County': 14865,
#   'Stearns County': 161075,
#   'Steele County': 36649,
#   'Stevens County': 9805,
#   'Swift County': 9266,
#   'Todd County': 24664,
#   'Traverse County': 3259,
#   'Wabasha County': 21627,
#   'Wadena County': 13682,
#   'Waseca County': 18612,
#   'Washington County': 262440,
#   'Watonwan County': 10897,
#   'Wilkin County': 6207,
#   'Winona County': 50484,
#   'Wright County': 138377,
#   'Yellow Medicine County': 9709},
#  'Mississippi': {'Adams County': 30693,
#   'Alcorn County': 36953,
#   'Amite County': 12297,
#   'Attala County': 18174,
#   'Benton County': 8259,
#   'Bolivar County': 30628,
#   'Calhoun County': 14361,
#   'Carroll County': 9947,
#   'Chickasaw County': 17103,
#   'Choctaw County': 8210,
#   'Claiborne County': 8988,
#   'Clarke County': 15541,
#   'Clay County': 19316,
#   'Coahoma County': 22124,
#   'Copiah County': 28065,
#   'Covington County': 18636,
#   'DeSoto County': 184945,
#   'Forrest County': 74897,
#   'Franklin County': 7713,
#   'George County': 24500,
#   'Greene County': 13586,
#   'Grenada County': 20758,
#   'Hancock County': 47632,
#   'Harrison County': 208080,
#   'Hinds County': 231840,
#   'Holmes County': 17010,
#   'Humphreys County': 8064,
#   'Issaquena County': 1327,
#   'Itawamba County': 23390,
#   'Jackson County': 143617,
#   'Jasper County': 16383,
#   'Jefferson County': 6990,
#   'Jefferson Davis County': 11128,
#   'Jones County': 68098,
#   'Kemper County': 9742,
#   'Lafayette County': 54019,
#   'Lamar County': 63343,
#   'Lauderdale County': 74125,
#   'Lawrence County': 12586,
#   'Leake County': 22786,
#   'Lee County': 85436,
#   'Leflore County': 28183,
#   'Lincoln County': 34153,
#   'Lowndes County': 58595,
#   'Madison County': 106272,
#   'Marion County': 24573,
#   'Marshall County': 35294,
#   'Monroe County': 35252,
#   'Montgomery County': 9775,
#   'Neshoba County': 29118,
#   'Newton County': 21018,
#   'Noxubee County': 10417,
#   'Oktibbeha County': 49587,
#   'Panola County': 34192,
#   'Pearl River County': 55535,
#   'Perry County': 11973,
#   'Pike County': 39288,
#   'Pontotoc County': 32174,
#   'Prentiss County': 25126,
#   'Quitman County': 6792,
#   'Rankin County': 155271,
#   'Scott County': 28124,
#   'Sharkey County': 4321,
#   'Simpson County': 26658,
#   'Smith County': 15916,
#   'Stone County': 18336,
#   'Sunflower County': 25110,
#   'Tallahatchie County': 13809,
#   'Tate County': 28321,
#   'Tippah County': 22015,
#   'Tishomingo County': 19383,
#   'Tunica County': 9632,
#   'Union County': 28815,
#   'Walthall County': 14286,
#   'Warren County': 45381,
#   'Washington County': 43909,
#   'Wayne County': 20183,
#   'Webster County': 9689,
#   'Wilkinson County': 8630,
#   'Winston County': 17955,
#   'Yalobusha County': 12108,
#   'Yazoo County': 29690},
#  'Missouri': {'Adair County': 25343,
#   'Andrew County': 17712,
#   'Atchison County': 5143,
#   'Audrain County': 25388,
#   'Barry County': 35789,
#   'Barton County': 11754,
#   'Bates County': 16172,
#   'Benton County': 19443,
#   'Bollinger County': 12133,
#   'Boone County': 180463,
#   'Buchanan County': 87364,
#   'Butler County': 42478,
#   'Caldwell County': 9020,
#   'Callaway County': 44743,
#   'Camden County': 46305,
#   'Cape Girardeau County': 78871,
#   'Carroll County': 8679,
#   'Carter County': 5982,
#   'Cass County': 105780,
#   'Cedar County': 14349,
#   'Chariton County': 7426,
#   'Christian County': 88595,
#   'Clark County': 6797,
#   'Clay County': 249948,
#   'Clinton County': 20387,
#   'Cole County': 76745,
#   'Cooper County': 17709,
#   'Crawford County': 23920,
#   'Dade County': 7561,
#   'Dallas County': 16878,
#   'Daviess County': 8278,
#   'DeKalb County': 12547,
#   'Dent County': 15573,
#   'Douglas County': 13185,
#   'Dunklin County': 29131,
#   'Franklin County': 103967,
#   'Gasconade County': 14706,
#   'Gentry County': 6571,
#   'Greene County': 293086,
#   'Grundy County': 9850,
#   'Harrison County': 8352,
#   'Henry County': 21824,
#   'Hickory County': 9544,
#   'Holt County': 4403,
#   'Howard County': 10001,
#   'Howell County': 40117,
#   'Iron County': 10125,
#   'Jackson County (including other portions of Kansas City)': 703011,
#   'Jasper County': 121328,
#   'Jefferson County': 225081,
#   'Johnson County': 54062,
#   'Knox County': 3959,
#   'Laclede County': 35723,
#   'Lafayette County': 32708,
#   'Lawrence County': 38355,
#   'Lewis County': 9776,
#   'Lincoln County': 59013,
#   'Linn County': 11920,
#   'Livingston County': 15227,
#   'McDonald County': 22837,
#   'Macon County': 15117,
#   'Madison County': 12088,
#   'Maries County': 8697,
#   'Marion County': 28530,
#   'Mercer County': 3617,
#   'Miller County': 25619,
#   'Mississippi County': 13180,
#   'Moniteau County': 16132,
#   'Monroe County': 8644,
#   'Montgomery County': 11551,
#   'Morgan County': 20627,
#   'New Madrid County': 17076,
#   'Newton County': 58236,
#   'Nodaway County': 22092,
#   'Oregon County': 10529,
#   'Osage County': 13615,
#   'Ozark County': 9174,
#   'Pemiscot County': 15805,
#   'Perry County': 19136,
#   'Pettis County': 42339,
#   'Phelps County': 44573,
#   'Pike County': 18302,
#   'Platte County': 104418,
#   'Polk County': 32149,
#   'Pulaski County': 52607,
#   'Putnam County': 4696,
#   'Ralls County': 10309,
#   'Randolph County': 24748,
#   'Ray County': 23018,
#   'Reynolds County': 6270,
#   'Ripley County': 13288,
#   'St. Charles County': 402022,
#   'St. Clair County': 9397,
#   'Ste. Genevieve County': 17894,
#   'St. Francois County': 67215,
#   'St. Louis County': 994205,
#   'Saline County': 22761,
#   'Schuyler County': 4660,
#   'Scotland County': 4902,
#   'Scott County': 38280,
#   'Shannon County': 8166,
#   'Shelby County': 5930,
#   'Stoddard County': 29025,
#   'Stone County': 31952,
#   'Sullivan County': 6089,
#   'Taney County': 55928,
#   'Texas County': 25398,
#   'Vernon County': 20563,
#   'Warren County': 35649,
#   'Washington County': 24730,
#   'Wayne County': 12873,
#   'Webster County': 39592,
#   'Worth County': 2013,
#   'Wright County': 18289,
#   'City of St. Louis': 300576},
#  'Montana': {'Beaverhead County': 9453,
#   'Big Horn County': 13319,
#   'Blaine County': 6681,
#   'Broadwater County': 6237,
#   'Carbon County': 10725,
#   'Carter County': 1252,
#   'Cascade County': 81366,
#   'Chouteau County': 5635,
#   'Custer County': 11402,
#   'Daniels County': 1690,
#   'Dawson County': 8613,
#   'Deer Lodge County': 9140,
#   'Fallon County': 2846,
#   'Fergus County': 11050,
#   'Flathead County': 103806,
#   'Gallatin County': 114434,
#   'Garfield County': 1258,
#   'Glacier County': 13753,
#   'Golden Valley County': 821,
#   'Granite County': 3379,
#   'Hill County': 16484,
#   'Jefferson County': 12221,
#   'Judith Basin County': 2007,
#   'Lake County': 30458,
#   'Lewis and Clark County': 69432,
#   'Liberty County': 2337,
#   'Lincoln County': 19980,
#   'McCone County': 1664,
#   'Madison County': 8600,
#   'Meagher County': 1862,
#   'Mineral County': 4397,
#   'Missoula County': 119600,
#   'Musselshell County': 4633,
#   'Park County': 16606,
#   'Petroleum County': 487,
#   'Phillips County': 3954,
#   'Pondera County': 5911,
#   'Powder River County': 1682,
#   'Powell County': 6890,
#   'Prairie County': 1077,
#   'Ravalli County': 43806,
#   'Richland County': 10803,
#   'Roosevelt County': 11004,
#   'Rosebud County': 8937,
#   'Sanders County': 12113,
#   'Sheridan County': 3309,
#   'Silver Bow County': 34915,
#   'Stillwater County': 9642,
#   'Sweet Grass County': 3737,
#   'Teton County': 6147,
#   'Toole County': 4736,
#   'Treasure County': 696,
#   'Valley County': 7396,
#   'Wheatland County': 2126,
#   'Wibaux County': 969,
#   'Yellowstone County': 161300},
#  'Nebraska': {'Adams County': 31363,
#   'Antelope County': 6298,
#   'Arthur County': 463,
#   'Banner County': 745,
#   'Blaine County': 465,
#   'Boone County': 5192,
#   'Box Butte County': 10783,
#   'Boyd County': 1919,
#   'Brown County': 2955,
#   'Buffalo County': 49659,
#   'Burt County': 6459,
#   'Butler County': 8016,
#   'Cass County': 26248,
#   'Cedar County': 8402,
#   'Chase County': 3924,
#   'Cherry County': 5689,
#   'Cheyenne County': 8910,
#   'Clay County': 6203,
#   'Colfax County': 10709,
#   'Cuming County': 8846,
#   'Custer County': 10777,
#   'Dakota County': 20026,
#   'Dawes County': 8589,
#   'Dawson County': 23595,
#   'Deuel County': 1794,
#   'Dixon County': 5636,
#   'Dodge County': 36565,
#   'Douglas County': 571327,
#   'Dundy County': 1693,
#   'Fillmore County': 5462,
#   'Franklin County': 2979,
#   'Frontier County': 2627,
#   'Furnas County': 4676,
#   'Gage County': 21513,
#   'Garden County': 1837,
#   'Garfield County': 1969,
#   'Gosper County': 1990,
#   'Grant County': 623,
#   'Greeley County': 2356,
#   'Hall County': 61353,
#   'Hamilton County': 9324,
#   'Harlan County': 3380,
#   'Hayes County': 922,
#   'Hitchcock County': 2762,
#   'Holt County': 10067,
#   'Hooker County': 682,
#   'Howard County': 6445,
#   'Jefferson County': 7046,
#   'Johnson County': 5071,
#   'Kearney County': 6495,
#   'Keith County': 8034,
#   'Keya Paha County': 806,
#   'Kimball County': 3632,
#   'Knox County': 8332,
#   'Lancaster County': 319090,
#   'Lincoln County': 34914,
#   'Logan County': 748,
#   'Loup County': 664,
#   'McPherson County': 494,
#   'Madison County': 35099,
#   'Merrick County': 7755,
#   'Morrill County': 4642,
#   'Nance County': 3519,
#   'Nemaha County': 6972,
#   'Nuckolls County': 4148,
#   'Otoe County': 16012,
#   'Pawnee County': 2613,
#   'Perkins County': 2891,
#   'Phelps County': 9034,
#   'Pierce County': 7148,
#   'Platte County': 33470,
#   'Polk County': 5213,
#   'Red Willow County': 10724,
#   'Richardson County': 7865,
#   'Rock County': 1357,
#   'Saline County': 14224,
#   'Sarpy County': 187196,
#   'Saunders County': 21578,
#   'Scotts Bluff County': 35618,
#   'Seward County': 17284,
#   'Sheridan County': 5246,
#   'Sherman County': 3001,
#   'Sioux County': 1166,
#   'Stanton County': 5920,
#   'Thayer County': 5003,
#   'Thomas County': 722,
#   'Thurston County': 7224,
#   'Valley County': 4158,
#   'Washington County': 20729,
#   'Wayne County': 9385,
#   'Webster County': 3487,
#   'Wheeler County': 783,
#   'York County': 13679},
#  'Nevada': {'Churchill County': 24909,
#   'Clark County': 2266715,
#   'Douglas County': 48905,
#   'Elko County': 52778,
#   'Esmeralda County': 873,
#   'Eureka County': 2029,
#   'Humboldt County': 16831,
#   'Lander County': 5532,
#   'Lincoln County': 5183,
#   'Lyon County': 57510,
#   'Mineral County': 4505,
#   'Nye County': 46523,
# ...
#   'Cameron County': 423163,
#   'Camp County': 13094,
#   'Carson County': 5926,
#   'Cass County': 30026,
#   'Castro County': 7530,
#   'Chambers County': 43837,
#   'Cherokee County': 52646,
#   'Childress County': 7306,
#   'Clay County': 10471,
#   'Cochran County': 2853,
#   'Coke County': 3387,
#   'Coleman County': 8175,
#   'Collin County': 1034730,
#   'Collingsworth County': 2920,
#   'Colorado County': 21493,
#   'Comal County': 156209,
#   'Comanche County': 13635,
#   'Concho County': 2726,
#   'Cooke County': 41257,
#   'Coryell County': 75951,
#   'Cottle County': 1398,
#   'Crane County': 4797,
#   'Crockett County': 3464,
#   'Crosby County': 5737,
#   'Culberson County': 2171,
#   'Dallam County': 7287,
#   'Dallas County': 2635516,
#   'Dawson County': 12728,
#   'Deaf Smith County': 18546,
#   'Delta County': 5331,
#   'Denton County': 887207,
#   'DeWitt County': 20160,
#   'Dickens County': 2211,
#   'Dimmit County': 10124,
#   'Donley County': 3278,
#   'Duval County': 11157,
#   'Eastland County': 18360,
#   'Ector County': 166223,
#   'Edwards County': 1932,
#   'Ellis County': 184826,
#   'El Paso County': 839238,
#   'Erath County': 42698,
#   'Falls County': 17297,
#   'Fannin County': 35514,
#   'Fayette County': 25346,
#   'Fisher County': 3830,
#   'Floyd County': 5712,
#   'Foard County': 1155,
#   'Fort Bend County': 811688,
#   'Franklin County': 10725,
#   'Freestone County': 19717,
#   'Frio County': 20306,
#   'Gaines County': 21492,
#   'Galveston County': 342139,
#   'Garza County': 6229,
#   'Gillespie County': 26988,
#   'Glasscock County': 1409,
#   'Goliad County': 7658,
#   'Gonzales County': 20837,
#   'Gray County': 21886,
#   'Grayson County': 136212,
#   'Gregg County': 123945,
#   'Grimes County': 28880,
#   'Guadalupe County': 166847,
#   'Hale County': 33406,
#   'Hall County': 2964,
#   'Hamilton County': 8461,
#   'Hansford County': 5399,
#   'Hardeman County': 3933,
#   'Hardin County': 57602,
#   'Harris County': 4713325,
#   'Harrison County': 66553,
#   'Hartley County': 5576,
#   'Haskell County': 5658,
#   'Hays County': 230191,
#   'Hemphill County': 3819,
#   'Henderson County': 82737,
#   'Hidalgo County': 868707,
#   'Hill County': 36649,
#   'Hockley County': 23021,
#   'Hood County': 61643,
#   'Hopkins County': 37084,
#   'Houston County': 22968,
#   'Howard County': 36664,
#   'Hudspeth County': 4886,
#   'Hunt County': 98594,
#   'Hutchinson County': 20938,
#   'Irion County': 1536,
#   'Jack County': 8935,
#   'Jackson County': 14760,
#   'Jasper County': 35529,
#   'Jeff Davis County': 2274,
#   'Jefferson County': 251565,
#   'Jim Hogg County': 5200,
#   'Jim Wells County': 40482,
#   'Johnson County': 175817,
#   'Jones County': 20083,
#   'Karnes County': 15601,
#   'Kaufman County': 136154,
#   'Kendall County': 47431,
#   'Kenedy County': 404,
#   'Kent County': 762,
#   'Kerr County': 52600,
#   'Kimble County': 4337,
#   'King County': 272,
#   'Kinney County': 3667,
#   'Kleberg County': 30680,
#   'Knox County': 3664,
#   'Lamar County': 49859,
#   'Lamb County': 12893,
#   'Lampasas County': 21428,
#   'La Salle County': 7520,
#   'Lavaca County': 20154,
#   'Lee County': 17239,
#   'Leon County': 17404,
#   'Liberty County': 88219,
#   'Limestone County': 23437,
#   'Lipscomb County': 3233,
#   'Live Oak County': 12207,
#   'Llano County': 21795,
#   'Loving County': 169,
#   'Lubbock County': 310569,
#   'Lynn County': 5951,
#   'McCulloch County': 7984,
#   'McLennan County': 256623,
#   'McMullen County': 743,
#   'Madison County': 14284,
#   'Marion County': 9854,
#   'Martin County': 5771,
#   'Mason County': 4274,
#   'Matagorda County': 36643,
#   'Maverick County': 58722,
#   'Medina County': 51584,
#   'Menard County': 2138,
#   'Midland County': 176832,
#   'Milam County': 24823,
#   'Mills County': 4873,
#   'Mitchell County': 8545,
#   'Montague County': 19818,
#   'Montgomery County': 607391,
#   'Moore County': 20940,
#   'Morris County': 12388,
#   'Motley County': 1200,
#   'Nacogdoches County': 65204,
#   'Navarro County': 50113,
#   'Newton County': 13595,
#   'Nolan County': 14714,
#   'Nueces County': 362294,
#   'Ochiltree County': 9836,
#   'Oldham County': 2112,
#   'Orange County': 83396,
#   'Palo Pinto County': 29189,
#   'Panola County': 23194,
#   'Parker County': 142878,
#   'Parmer County': 9605,
#   'Pecos County': 15823,
#   'Polk County': 51353,
#   'Potter County': 117415,
#   'Presidio County': 6704,
#   'Rains County': 12514,
#   'Randall County': 137713,
#   'Reagan County': 3849,
#   'Real County': 3452,
#   'Red River County': 12023,
#   'Reeves County': 15976,
#   'Refugio County': 6948,
#   'Roberts County': 854,
#   'Robertson County': 17074,
#   'Rockwall County': 104915,
#   'Runnels County': 10264,
#   'Rusk County': 54406,
#   'Sabine County': 10542,
#   'San Augustine County': 8237,
#   'San Jacinto County': 28859,
#   'San Patricio County': 66730,
#   'San Saba County': 6055,
#   'Schleicher County': 2793,
#   'Scurry County': 16703,
#   'Shackelford County': 3265,
#   'Shelby County': 25274,
#   'Sherman County': 3022,
#   'Smith County': 232751,
#   'Somervell County': 9128,
#   'Starr County': 64633,
#   'Stephens County': 9366,
#   'Sterling County': 1291,
#   'Stonewall County': 1350,
#   'Sutton County': 3776,
#   'Swisher County': 7397,
#   'Tarrant County': 2102515,
#   'Taylor County': 138034,
#   'Terrell County': 776,
#   'Terry County': 12337,
#   'Throckmorton County': 1501,
#   'Titus County': 32750,
#   'Tom Green County': 119200,
#   'Travis County': 1273954,
#   'Trinity County': 14651,
#   'Tyler County': 21672,
#   'Upshur County': 41753,
#   'Upton County': 3657,
#   'Uvalde County': 26741,
#   'Val Verde County': 49025,
#   'Van Zandt County': 56590,
#   'Victoria County': 92084,
#   'Walker County': 72971,
#   'Waller County': 55246,
#   'Ward County': 11998,
#   'Washington County': 35882,
#   'Webb County': 276652,
#   'Wharton County': 41556,
#   'Wheeler County': 5056,
#   'Wichita County': 132230,
#   'Wilbarger County': 12769,
#   'Willacy County': 21358,
#   'Williamson County': 590551,
#   'Wilson County': 51070,
#   'Winkler County': 8010,
#   'Wise County': 69984,
#   'Wood County': 45539,
#   'Yoakum County': 8713,
#   'Young County': 18010,
#   'Zapata County': 14179,
#   'Zavala County': 11840},
#  'Utah': {'Beaver County': 6710,
#   'Box Elder County': 56046,
#   'Cache County': 128289,
#   'Carbon County': 20463,
#   'Daggett County': 950,
#   'Davis County': 355481,
#   'Duchesne County': 19938,
#   'Emery County': 10012,
#   'Garfield County': 5051,
#   'Grand County': 9754,
#   'Iron County': 54839,
#   'Juab County': 12017,
#   'Kane County': 7886,
#   'Millard County': 13188,
#   'Morgan County': 12124,
#   'Piute County': 1479,
#   'Rich County': 2483,
#   'Salt Lake County': 1160437,
#   'San Juan County': 15308,
#   'Sanpete County': 30939,
#   'Sevier County': 21620,
#   'Summit County': 42145,
#   'Tooele County': 72259,
#   'Uintah County': 35734,
#   'Utah County': 636235,
#   'Wasatch County': 34091,
#   'Washington County': 177556,
#   'Wayne County': 2711,
#   'Weber County': 260213},
#  'Vermont': {'Addison County': 36777,
#   'Bennington County': 35470,
#   'Caledonia County': 29993,
#   'Chittenden County': 163774,
#   'Essex County': 6163,
#   'Franklin County': 49402,
#   'Grand Isle County': 7235,
#   'Lamoille County': 25362,
#   'Orange County': 28892,
#   'Orleans County': 27037,
#   'Rutland County': 58191,
#   'Washington County': 58409,
#   'Windham County': 42222,
#   'Windsor County': 55062},
#  'Virginia': {'Accomack County': 32316,
#   'Albemarle County': 109330,
#   'Alleghany County': 14860,
#   'Amelia County': 13145,
#   'Amherst County': 31605,
#   'Appomattox County': 15911,
#   'Arlington County': 236842,
#   'Augusta County': 75558,
#   'Bath County': 4147,
#   'Bedford County': 78997,
#   'Bland County': 6280,
#   'Botetourt County': 33419,
#   'Brunswick County': 16231,
#   'Buchanan County': 21004,
#   'Buckingham County': 17148,
#   'Campbell County': 54885,
#   'Caroline County': 30725,
#   'Carroll County': 29791,
#   'Charles City County': 6963,
#   'Charlotte County': 11880,
#   'Chesterfield County': 352802,
#   'Clarke County': 14619,
#   'Craig County': 5131,
#   'Culpeper County': 52605,
#   'Cumberland County': 9932,
#   'Dickenson County': 14318,
#   'Dinwiddie County': 28544,
#   'Essex County': 10953,
#   'Fairfax County': 1147532,
#   'Fauquier County': 71222,
#   'Floyd County': 15749,
#   'Fluvanna County': 27270,
#   'Franklin County': 56042,
#   'Frederick County': 89313,
#   'Giles County': 16720,
#   'Gloucester County': 37348,
#   'Goochland County': 23753,
#   'Grayson County': 15550,
#   'Greene County': 19819,
#   'Greensville County': 11336,
#   'Halifax County': 33911,
#   'Hanover County': 107766,
#   'Henrico County': 330818,
#   'Henry County': 50557,
#   'Highland County': 2190,
#   'Isle of Wight County': 37109,
#   'James City County': 76523,
#   'King and Queen County': 7025,
#   'King George County': 26836,
#   'King William County': 17148,
#   'Lancaster County': 10603,
#   'Lee County': 23423,
#   'Loudoun County': 413538,
#   'Louisa County': 37591,
#   'Lunenburg County': 12196,
#   'Madison County': 13261,
#   'Matthews County': 8834,
#   'Mecklenburg County': 30587,
#   'Middlesex County': 10582,
#   'Montgomery County': 98535,
#   'Nelson County': 14930,
#   'New Kent County': 23091,
#   'Northampton County': 11710,
#   'Northumberland County': 12095,
#   'Nottoway County': 15232,
#   'Orange County': 37051,
#   'Page County': 23902,
#   'Patrick County': 17608,
#   'Pittsylvania County': 60354,
#   'Powhatan County': 29652,
#   'Prince Edward County': 22802,
#   'Prince George County': 38353,
#   'Prince William County': 470335,
#   'Pulaski County': 34027,
#   'Rappahannock County': 7370,
#   'Richmond County': 9023,
#   'Roanoke County': 94186,
#   'Rockbridge County': 22573,
#   'Rockingham County': 81948,
#   'Russell County': 26586,
#   'Scott County': 21566,
#   'Shenandoah County': 43616,
#   'Smyth County': 30104,
#   'Southampton County': 17631,
#   'Spotsylvania County': 136215,
#   'Stafford County': 152882,
#   'Surry County': 6422,
#   'Sussex County': 11159,
#   'Tazewell County': 40595,
#   'Warren County': 40164,
#   'Washington County': 53740,
#   'Westmoreland County': 18015,
#   'Wise County': 37383,
#   'Wythe County': 28684,
#   'York County': 68280,
#   'Alexandria City': 159428,
#   'Bristol city': 16762,
#   'Buena Vista city': 6478,
#   'Charlottesville City': 47266,
#   'Chesapeake City': 244835,
#   'Colonial Heights city': 17370,
#   'Covington city': 5538,
#   'Danville City': 40044,
#   'Emporia city': 5346,
#   'Fairfax city': 24019,
#   'Falls Church city': 14617,
#   'Franklin city': 7967,
#   'Fredericksburg City': 29036,
#   'Galax city': 6347,
#   'Hampton city': 134510,
#   'Harrisonburg City': 53016,
#   'Hopewell city': 22529,
#   'Lexington city': 7446,
#   'Lynchburg city': 82168,
#   'Manassas City': 41085,
#   'Manassas Park city': 17478,
#   'Martinsville city': 12554,
#   'Newport News City': 179225,
#   'Norfolk City': 242742,
#   'Norton city': 3981,
#   'Petersburg city': 31346,
#   'Poquoson city': 12271,
#   'Portsmouth City': 94398,
#   'Radford city': 18249,
#   'Richmond City': 230436,
#   'Roanoke city': 99143,
#   'Salem city': 25301,
#   'Staunton city': 24932,
#   'Suffolk City': 92108,
#   'Virginia Beach City': 449974,
#   'Waynesboro city': 22630,
#   'Williamsburg City': 14954,
#   'Winchester city': 28078},
#  'Washington': {'Adams County': 19983,
#   'Asotin County': 22582,
#   'Benton County': 204390,
#   'Chelan County': 77200,
#   'Clallam County': 77331,
#   'Clark County': 488241,
#   'Columbia County': 3985,
#   'Cowlitz County': 110593,
#   'Douglas County': 43429,
#   'Ferry County': 7627,
#   'Franklin County': 95222,
#   'Garfield County': 2225,
#   'Grant County': 97733,
#   'Grays Harbor County': 75061,
#   'Island County': 85141,
#   'Jefferson County': 32221,
#   'King County': 2252782,
#   'Kitsap County': 271473,
#   'Kittitas County': 47935,
#   'Klickitat County': 22425,
#   'Lewis County': 80707,
#   'Lincoln County': 10939,
#   'Mason County': 66768,
#   'Okanogan County': 42243,
#   'Pacific County': 22471,
#   'Pend Oreille County': 13724,
#   'Pierce County': 904980,
#   'San Juan County': 17582,
#   'Skagit County': 129205,
#   'Skamania County': 12083,
#   'Snohomish County': 822083,
#   'Spokane County': 522798,
#   'Stevens County': 45723,
#   'Thurston County': 290536,
#   'Wahkiakum County': 4488,
#   'Walla Walla County': 60760,
#   'Whatcom County': 229247,
#   'Whitman County': 50104,
#   'Yakima County': 250873},
#  'West Virginia': {'Barbour County': 16441,
#   'Berkeley County': 119171,
#   'Boone County': 21457,
#   'Braxton County': 13957,
#   'Brooke County': 21939,
#   'Cabell County': 91945,
#   'Calhoun County': 7109,
#   'Clay County': 8508,
#   'Doddridge County': 8448,
#   'Fayette County': 42406,
#   'Gilmer County': 7823,
#   'Grant County': 11568,
#   'Greenbrier County': 34662,
#   'Hampshire County': 23175,
#   'Hancock County': 28810,
#   'Hardy County': 13776,
#   'Harrison County': 67256,
#   'Jackson County': 28576,
#   'Jefferson County': 57146,
#   'Kanawha County': 178124,
#   'Lewis County': 15907,
#   'Lincoln County': 20409,
#   'Logan County': 32019,
#   'McDowell County': 17624,
#   'Marion County': 56072,
#   'Marshall County': 30531,
#   'Mason County': 26516,
#   'Mercer County': 58758,
#   'Mineral County': 26868,
#   'Mingo County': 23424,
#   'Monongalia County': 105612,
#   'Monroe County': 13275,
#   'Morgan County': 17884,
#   'Nicholas County': 24496,
#   'Ohio County': 41411,
#   'Pendleton County': 6969,
#   'Pleasants County': 7460,
#   'Pocahontas County': 8247,
#   'Preston County': 33432,
#   'Putnam County': 56450,
#   'Raleigh County': 73361,
#   'Randolph County': 28695,
#   'Ritchie County': 9554,
#   'Roane County': 13688,
#   'Summers County': 12573,
#   'Taylor County': 16695,
#   'Tucker County': 6839,
#   'Tyler County': 8591,
#   'Upshur County': 24176,
#   'Wayne County': 39402,
#   'Webster County': 8114,
#   'Wetzel County': 15065,
#   'Wirt County': 5821,
#   'Wood County': 83518,
#   'Wyoming County': 20394},
#  'Wisconsin': {'Adams County': 20220,
#   'Ashland County': 15562,
#   'Barron County': 45244,
#   'Bayfield County': 15036,
#   'Brown County': 264542,
#   'Buffalo County': 13031,
#   'Burnett County': 15414,
#   'Calumet County': 50089,
#   'Chippewa County': 64658,
#   'Clark County': 34774,
#   'Columbia County': 57532,
#   'Crawford County': 16131,
#   'Dane County': 546695,
#   'Dodge County': 87839,
#   'Door County': 27668,
#   'Douglas County': 43150,
#   'Dunn County': 45368,
#   'Eau Claire County': 104646,
#   'Florence County': 4295,
#   'Fond du Lac County': 103403,
#   'Forest County': 9004,
#   'Grant County': 51439,
#   'Green County': 36960,
#   'Green Lake County': 18913,
#   'Iowa County': 23678,
#   'Iron County': 5687,
#   'Jackson County': 20643,
#   'Jefferson County': 84769,
#   'Juneau County': 26687,
#   'Kenosha County': 169561,
#   'Kewaunee County': 20434,
#   'La Crosse County': 118016,
#   'Lafayette County': 16665,
#   'Langlade County': 19189,
#   'Lincoln County': 27593,
#   'Manitowoc County': 78981,
#   'Marathon County': 135692,
#   'Marinette County': 40350,
#   'Marquette County': 15574,
#   'Menominee County': 4556,
#   'Milwaukee County': 945726,
#   'Monroe County': 46253,
#   'Oconto County': 37930,
#   'Oneida County': 35595,
#   'Outagamie County': 187885,
#   'Ozaukee County': 89221,
#   'Pepin County': 7287,
#   'Pierce County': 42754,
#   'Polk County': 43783,
#   'Portage County': 70772,
#   'Price County': 13351,
#   'Racine County': 196311,
#   'Richland County': 17252,
#   'Rock County': 163354,
#   'Rusk County': 14178,
#   'St. Croix County': 90687,
#   'Sauk County': 64442,
#   'Sawyer County': 16558,
#   'Shawano County': 40899,
#   'Sheboygan County': 115340,
#   'Taylor County': 20343,
#   'Trempealeau County': 29649,
#   'Vernon County': 30822,
#   'Vilas County': 22195,
#   'Walworth County': 103868,
#   'Washburn County': 15720,
#   'Washington County': 136034,
#   'Waukesha County': 404198,
#   'Waupaca County': 50990,
#   'Waushara County': 24443,
#   'Winnebago County': 171907,
#   'Wood County': 72999},
#  'Wyoming': {'Albany County': 38880,
#   'Big Horn County': 11790,
#   'Campbell County': 46341,
#   'Carbon County': 14800,
#   'Converse County': 13822,
#   'Crook County': 7584,
#   'Fremont County': 39261,
#   'Goshen County': 13211,
#   'Hot Springs County': 4413,
#   'Johnson County': 8445,
#   'Laramie County': 99500,
#   'Lincoln County': 19830,
#   'Natrona County': 79858,
#   'Niobrara County': 2356,
#   'Park County': 29194,
#   'Platte County': 8393,
#   'Sheridan County': 30485,
#   'Sublette County': 9831,
#   'Sweetwater County': 42343,
#   'Teton County': 23464,
#   'Uinta County': 20226,
#   'Washakie County': 7805,
#   'Weston County': 6927}}

# %%
pop_county_list = []
for state in population_dict.keys():
    state_county_pop_i = pd.DataFrame.from_dict(population_dict[state], orient = "index")
    state_county_pop_i['state'] = state
    state_county_pop_i = state_county_pop_i.reset_index(inplace = False)
    state_county_pop_i.columns = ['county', 'population', 'state']
    state_county_pop_i = state_county_pop_i[['state', 'county', 'population']]
    pop_county_list.append(state_county_pop_i)
# print(pop_county_list)
state_county_pop = pd.concat(pop_county_list)
state_county_pop
# Out:
#       state             county  population
# 0   Alabama     Autauga County       55869
# 1   Alabama     Baldwin County      223234
# 2   Alabama     Barbour County       24686
# 3   Alabama        Bibb County       22394
# 4   Alabama      Blount County       57826
# ..      ...                ...         ...
# 18  Wyoming  Sweetwater County       42343
# 19  Wyoming       Teton County       23464
# 20  Wyoming       Uinta County       20226
# 21  Wyoming    Washakie County        7805
# 22  Wyoming      Weston County        6927
#
# [3145 rows x 3 columns]

# %%
covid_df

covid_df_merged = pd.merge(covid_df, state_county_pop,
                           how = 'left',
                           left_on = ['state','county'], right_on = ['state','county'])

covid_df_merged['cases_per_100k'] = covid_df_merged['cases'] / covid_df_merged['population'] * 100000
covid_df_merged['cases_per_100k'] = covid_df_merged['cases_per_100k'].astype('int')
covid_df_merged
# Out:
#         state             county  seven_d_cases  seven_d_deaths  cases  \
# 0     Alabama     Autauga County             41               0   9351
# 1     Alabama     Baldwin County            139               4  35221
# 2     Alabama     Barbour County             17               0   3329
# 3     Alabama        Bibb County             28               0   3859
# 4     Alabama      Blount County             42               0   9246
# ...       ...                ...            ...             ...    ...
# 3076  Wyoming  Sweetwater County             69               0   6275
# 3077  Wyoming       Teton County             25               0   4679
# 3078  Wyoming       Uinta County             28               0   3248
# 3079  Wyoming    Washakie County             10               0   1148
# 3080  Wyoming      Weston County              6               0    845
#
#       deaths  population  cases_per_100k
# 0        119       55869           16737
# 1        417      223234           15777
# 2         67       24686           13485
# 3         75       22394           17232
# 4        146       57826           15989
# ...      ...         ...             ...
# 3076      51       42343           14819
# 3077      11       23464           19941
# 3078      16       20226           16058
# 3079      27        7805           14708
# 3080       6        6927           12198
#
# [3081 rows x 8 columns]

# %%
def convert_to_pandas(covid_data):
    
    # YOUR CODE HERE
    # first, make a dataframe from dictionary values of covid data
    new_df = pd.DataFrame.from_dict({(i,j): covid_data[i][j] 
                           for i in covid_data.keys() 
                           for j in covid_data[i].keys()},
                       orient = 'index')
    
    covid_df = new_df.reset_index(inplace = False)
    covid_df.rename(columns = {'level_0':'state',
                               'level_1':'county'}, inplace = True)
    
    # second, make another dataframe
    # from dictionary values of population data
    pop_county_list = []
    for state in population_dict.keys():
        state_county_pop_i = pd.DataFrame.from_dict(population_dict[state], orient = "index")
        state_county_pop_i['state'] = state
        state_county_pop_i = state_county_pop_i.reset_index(inplace = False)
        state_county_pop_i.columns = ['county', 'population', 'state']
        state_county_pop_i = state_county_pop_i[['state', 'county', 'population']]
        pop_county_list.append(state_county_pop_i)
    state_county_pop = pd.concat(pop_county_list)
    
    # third, merge the two dataframes so that we can compute cases per 100k
    covid_df_merged = pd.merge(covid_df, state_county_pop,
                           how = 'left',
                           left_on = ['state','county'], right_on = ['state','county'])
    covid_df_merged['cases_per_100k'] = covid_df_merged['cases'] / covid_df_merged['population'] * 100000
    
    # covid_df_merged['cases_per_100k'] = covid_df_merged['cases_per_100k'].astype('int')

    
    # END OF YOUR CODE HERE
    return covid_df_merged

# %% [markdown]
# Run the cell below (no changes necessary) to execute your code above and inspect the results.

# %%
covid_df = convert_to_pandas(covid_data)
covid_df
# Out:
#         state             county  seven_d_cases  seven_d_deaths  cases  \
# 0     Alabama     Autauga County             41               0   9351
# 1     Alabama     Baldwin County            139               4  35221
# 2     Alabama     Barbour County             17               0   3329
# 3     Alabama        Bibb County             28               0   3859
# 4     Alabama      Blount County             42               0   9246
# ...       ...                ...            ...             ...    ...
# 3076  Wyoming  Sweetwater County             69               0   6275
# 3077  Wyoming       Teton County             25               0   4679
# 3078  Wyoming       Uinta County             28               0   3248
# 3079  Wyoming    Washakie County             10               0   1148
# 3080  Wyoming      Weston County              6               0    845
#
#       deaths  population  cases_per_100k
# 0        119       55869    16737.367771
# 1        417      223234    15777.614521
# 2         67       24686    13485.376327
# 3         75       22394    17232.294365
# 4        146       57826    15989.347352
# ...      ...         ...             ...
# 3076      51       42343    14819.450677
# 3077      11       23464    19941.186498
# 3078      16       20226    16058.538515
# 3079      27        7805    14708.520179
# 3080       6        6927    12198.642991
#
# [3081 rows x 8 columns]

# %% [markdown]
# <div class='exercise'><b> Exercise 3.2 [5 pts]: Simple analytics</b>
#
# Complete the `calculate_county_stats2()` function, **which should obtain identical information (other than ties) as problem 2.2, but now using the PANDAS `covid_df` DataFrame.**
#
# That is, it should calculates:
# 1. the single county (and the state to which it belongs) that has the **lowest rate** of COVID cases per 100k people
# 2. the single county (and the state to which it belongs) that has the **highest rate** of COVID cases per 100k people
#
# **NOTES:**
# - If there are ties, return any of the tied counties
# - Place your resulting variables within the `print()` statements that we provide (don't just manually type your textual answers in the blanks)
# - The values you report should be Floating point numbers (e.g., 3.4), not Integers (e.g., 3).
#
# </div>

# %%
# max(covid_df['cases_per_100k']) == covid_df['cases_per_100k']
maxrow_cases_per_100k = covid_df['cases_per_100k'].idxmax()
# covid_df.iloc[maxrow_cases_per_100k]

minrow_cases_per_100k = covid_df['cases_per_100k'].idxmin()
# covid_df.iloc[minrow_cases_per_100k]

covid_df.iloc[[minrow_cases_per_100k, maxrow_cases_per_100k]]
# Out:
#      state                      county  seven_d_cases  seven_d_deaths  cases  \
# 79  Alaska  Lake and Peninsula Borough              0               0      0
# 70  Alaska         Bristol Bay Borough              0               0    608
#
#     deaths  population  cases_per_100k
# 79       0        1592        0.000000
# 70       2         836    72727.272727

# %%
def calculate_county_stats2(df):

    # YOUR CODE HERE
    maxrow_cases_per_100k = covid_df['cases_per_100k'].idxmax()
    minrow_cases_per_100k = covid_df['cases_per_100k'].idxmin()
    
    df_maxmin = df.iloc[[minrow_cases_per_100k, maxrow_cases_per_100k]]
    
    return df_maxmin
    # END OF YOUR CODE HERE

# %% [markdown]
# Run the cell below (no changes necessary) to execute your code above

# %%
calculate_county_stats2(covid_df)
# Out:
#      state                      county  seven_d_cases  seven_d_deaths  cases  \
# 79  Alaska  Lake and Peninsula Borough              0               0      0
# 70  Alaska         Bristol Bay Borough              0               0    608
#
#     deaths  population  cases_per_100k
# 79       0        1592        0.000000
# 70       2         836    72727.272727

# %% [markdown]
# <div class='exercise'><b> Exercise 3.3 [5 pts]: Simple analytics</b>
#
# Complete the `calculate_state_deaths2()` function, **which should obtain identical information as problem 2.3 (other than ties), but now using the PANDAS `covid_df` DataFrame.**
# 1. the state that has the **lowest number** of deaths
# 2. the state that has the **highest number** of deaths
#
# **NOTES:**
# - If there are ties, return any of the tied states
# - Place your resulting variables within the `print()` statements that we provide (don't just manually type your textual answers in the blanks)
# - The values you report should be Integers, not Floating point numbers.
# </div>

# %%
def calculate_state_deaths2(df):

    # YOUR CODE HERE
    # first need to group and sum counties into states
    df_bystate = df.groupby(['state']).sum()

    # and add a state column
    df_bystate = df_bystate.reset_index(inplace = False)


    # but need to recalculate the cases_per_100k, since it doesn't make sense to sum a rate
    df_bystate['cases_per_100k'] = df_bystate['cases'] / df_bystate['population'] * 100000

    # max(covid_df['cases_per_100k']) == covid_df['cases_per_100k']
    maxrow_deaths = df_bystate['deaths'].idxmax()
    minrow_deaths = df_bystate['deaths'].idxmin()

    df_maxmin = df_bystate.iloc[[minrow_deaths, maxrow_deaths]]
    
    return df_maxmin
    # END OF YOUR CODE HERE

# %% [markdown]
# Run the cell below (no changes necessary) to execute your code above

# %%
calculate_state_deaths2(covid_df)
# Out:
#          state  seven_d_cases  seven_d_deaths    cases  deaths  population  \
# 11      Hawaii            177               0    19510     152      441309
# 4   California           7417              83  4321742   66016    38630674
#
#     cases_per_100k
# 11     4420.938617
# 4     11187.332636

# %% [markdown]
# <div class='exercise'><b> Exercise 3.4 [5 pts]: Simple analytics</b>
#
# Complete the `calculate_state_deathrate2()` function, **which should obtain identical information as problem 2.4, but now using the PANDAS `covid_df` DataFrame.** That is, return:
#
# 1. The state that has the **lowest rate** of deaths based on its entire population
# 2. The state that has the **highest rate** of deaths based on its entire population
#
# **NOTES:**
# - Just as in, 2.4, to calculate a state's population, we are asserting that is sufficient to sum the population over all counties -- and that each county's population can be calculated simply from the data fields stored within `covid_data`.
# - Just as in 2.4, counties with 0 COVID cases should contibute 0 to the total population of the state.
# - Round your results to the a single person (e.g., "1 out of every 2703 people has died" not 2703.4)
# - Place your resulting variables within the blanks of the `print()` statements that we provide (don't just manually type your textual answers in the blanks)
# </div>

# %%
def calculate_state_deathrate2(df):

    # YOUR CODE HERE
    # first need to group and sum counties into states
    df_bystate = df.groupby(['state']).sum()

    # and add a state column
    df_bystate = df_bystate.reset_index(inplace = False)


    # but need to recalculate the cases_per_100k, since it doesn't make sense to sum a rate
    df_bystate['cases_per_100k'] = df_bystate['cases'] / df_bystate['population'] * 100000
    
    # calculate deathrate
    df_bystate['deathrate'] = df_bystate['deaths'] / df_bystate['population']

    # max(covid_df['cases_per_100k']) == covid_df['cases_per_100k']
    maxrow_deathrate = df_bystate['deathrate'].idxmax()
    minrow_deathrate = df_bystate['deathrate'].idxmin()

    df_maxmin = df_bystate.iloc[[minrow_deathrate, maxrow_deathrate]]
    
    return df_maxmin
    # END OF YOUR CODE HERE

print(calculate_state_deathrate2(covid_df)['state'].iloc[0] + " has the lowest COVID death rate; 1 out of every " + str(int(np.reciprocal(calculate_state_deathrate2(covid_df)['deathrate'].iloc[0]))) + " people has died")
print(calculate_state_deathrate2(covid_df)['state'].iloc[1] + " has the highest COVID death rate; 1 out of every " + str(int(np.reciprocal(calculate_state_deathrate2(covid_df)['deathrate'].iloc[1]))) + " people has died")
# Out:
# Hawaii has the lowest COVID death rate; 1 out of every 2903 people has died
# Mississippi has the highest COVID death rate; 1 out of every 328 people has died

# %% [markdown]
# Run the cell below (no changes necessary) to execute your code above

# %%
calculate_state_deathrate2(covid_df)
# Out:
#           state  seven_d_cases  seven_d_deaths   cases  deaths  population  \
# 11       Hawaii            177               0   19510     152      441309
# 24  Mississippi           1827              47  466145    9061     2976149
#
#     cases_per_100k  deathrate
# 11     4420.938617   0.000344
# 24    15662.690275   0.003045

# %% [markdown]
# These are highly alarming and tragic statistics, and doing calculations like this can really put the severity of the virus into a grounded perspective. In order to perfectly understand the virus and its spread, everyone would be tested and we would have contact tracing. Without getting into socio-political issues, our point is that (1) we wish to better understand the virus' effects; (2) naturally, any real-world data is messy, and thus we will never have _perfect_ data.
#
#
# Let's now attempt to understand _some_ of the uncertainty around our COVID data. It's reasonable to believe that the # of COVID deaths is fairly reliable. That is, there are inevitably some false negatives -- people who died of COVID but were not accounted for, as other conditions were listed as the cause. However, the number of false positives is probably minimal -- if someone was denoted as dying from COVID, it's probably true. It's also the case that every disease has a mortality rate. For example, if 1,000 randomly-selected people contracted COVID, $N\%$ of them will die. We'd imagine that this percentage should be pretty constant throughout all people in the United States. Of course, we can think of reasons for this rate to not be perfectly consistent, as some people are at higher risk (e.g., older folks, people with pre-existing conditions, etc). Yet, we can imagine that this natural *variance* in the population to be fairly uniform throughout the USA at large. To this end, if all counties were equal in their **testing**, we ought to see a consistent ratio between: (a) the # of people who died from COVID; and (b) the # of people who tested positive for COVID. Within the medical domain, this ratio is referred to as the `case_fatality_rate`. For example, if 750 people tested positive for COVID, and 75 of those people died, then our `case_fatality_rate` would be 0.1 (meaning 10%).

# %% [markdown]
# <div class='exercise'><b>Exercise 3.5 [5 pts]: Further analytics</b>
#
# Complete the `add_death_stats()` function below, which should add 3 new columns:
# - `case_fatality_rate`
# - `# covid deaths per 100k` and
# - `population`
#
# And return the updated DataFrame **sorted by `case_fatality_rate` in ascending order**
#
# **NOTES:**
#
# - `add_death_stats()` should return a new DataFrame that has 8 columns:
#     - county
#     - state
#     - population
#     - \# total covid cases
#     - \# covid cases per 100k
#     - \# covid deaths
#     - \# covid deaths per 100k
#     - case_fatality_rate
# - DataFrame should be sorted by `case_fatality_rate` in ascending order
# - Again, the values for `case_fatality_rate` should be < 1. A value of 1 would mean that 100% of people who tested positive for COVID also died.
# - `# covid deaths per 100k` is simply defined as the # of COVID deaths for every 100,000 people. We calculate this on a per-county basis.
# - Make sure you inspect your results thoroughly. You may have to address the results of divisions by zero (or prevent these divisions in the first place).
# </div>

# %%
covid_df
# Out:
#         state             county  seven_d_cases  seven_d_deaths  cases  \
# 0     Alabama     Autauga County             41               0   9351
# 1     Alabama     Baldwin County            139               4  35221
# 2     Alabama     Barbour County             17               0   3329
# 3     Alabama        Bibb County             28               0   3859
# 4     Alabama      Blount County             42               0   9246
# ...       ...                ...            ...             ...    ...
# 3076  Wyoming  Sweetwater County             69               0   6275
# 3077  Wyoming       Teton County             25               0   4679
# 3078  Wyoming       Uinta County             28               0   3248
# 3079  Wyoming    Washakie County             10               0   1148
# 3080  Wyoming      Weston County              6               0    845
#
#       deaths  population  cases_per_100k
# 0        119       55869    16737.367771
# 1        417      223234    15777.614521
# 2         67       24686    13485.376327
# 3         75       22394    17232.294365
# 4        146       57826    15989.347352
# ...      ...         ...             ...
# 3076      51       42343    14819.450677
# 3077      11       23464    19941.186498
# 3078      16       20226    16058.538515
# 3079      27        7805    14708.520179
# 3080       6        6927    12198.642991
#
# [3081 rows x 8 columns]

# %%
def add_death_stats(df):
    
    # can add an infintesimal or fillna after the fact to handle nans from divide by 0.
    
    # YOUR CODE HERE
    df['deaths_per_100k'] = df['deaths'] / df['population'] * 100000
    df['case_fatality_rate'] = df['deaths'] / df['cases']
    
    # now sort by case fatality rate, ascending
    df = df.sort_values(by = 'case_fatality_rate', ascending = True)
    
    # fill NaNs
    df = df.fillna(0)
    
    # since we did fillna AFTER sorting, there are values of 0 at the head and at the tail
    # those at the head refer to counties with positive cases but zero deaths
    # those at the tail refer to counties with zero cases
    
    # select appropriate columns
    df = df[['state', 'county', 'population', 'cases', 'cases_per_100k', 'deaths', 'deaths_per_100k', 'case_fatality_rate']]
    
    # END OF YOUR CODE HERE
    return df

# %%
add_death_stats(covid_df)
# Out:
#            state                      county  population  cases  \
# 1675    Nebraska                Hayes County         922     61
# 1674    Nebraska               Harlan County        3380    219
# 2782        Utah                Wayne County        2711    186
# 2919  Washington             San Juan County       17582    277
# 1684    Nebraska            Keya Paha County         806     54
# ...          ...                         ...         ...    ...
# 1670    Nebraska                Grant County         623     41
# 434      Georgia             Glascock County        2971    176
# 1784  New Mexico              Harding County         625     14
# 79        Alaska  Lake and Peninsula Borough        1592      0
# 533       Hawaii              Kalawao County          86      0
#
#       cases_per_100k  deaths  deaths_per_100k  case_fatality_rate
# 1675     6616.052061       0         0.000000            0.000000
# 1674     6479.289941       0         0.000000            0.000000
# 2782     6860.936924       0         0.000000            0.000000
# 2919     1575.474918       0         0.000000            0.000000
# 1684     6699.751861       0         0.000000            0.000000
# ...              ...     ...              ...                 ...
# 1670     6581.059390       4       642.054575            0.097561
# 434      5923.931336      19       639.515315            0.107955
# 1784     2240.000000       2       320.000000            0.142857
# 79          0.000000       0         0.000000            0.000000
# 533         0.000000       0         0.000000            0.000000
#
# [3081 rows x 8 columns]

# %% [markdown]
# Run the cell below (no changes necessary) to execute your code above

# %%
covid_updated = add_death_stats(covid_df)
covid_updated
# Out:
#            state                      county  population  cases  \
# 1675    Nebraska                Hayes County         922     61
# 1674    Nebraska               Harlan County        3380    219
# 2782        Utah                Wayne County        2711    186
# 2919  Washington             San Juan County       17582    277
# 1684    Nebraska            Keya Paha County         806     54
# ...          ...                         ...         ...    ...
# 1670    Nebraska                Grant County         623     41
# 434      Georgia             Glascock County        2971    176
# 1784  New Mexico              Harding County         625     14
# 79        Alaska  Lake and Peninsula Borough        1592      0
# 533       Hawaii              Kalawao County          86      0
#
#       cases_per_100k  deaths  deaths_per_100k  case_fatality_rate
# 1675     6616.052061       0         0.000000            0.000000
# 1674     6479.289941       0         0.000000            0.000000
# 2782     6860.936924       0         0.000000            0.000000
# 2919     1575.474918       0         0.000000            0.000000
# 1684     6699.751861       0         0.000000            0.000000
# ...              ...     ...              ...                 ...
# 1670     6581.059390       4       642.054575            0.097561
# 434      5923.931336      19       639.515315            0.107955
# 1784     2240.000000       2       320.000000            0.142857
# 79          0.000000       0         0.000000            0.000000
# 533         0.000000       0         0.000000            0.000000
#
# [3081 rows x 8 columns]

# %%
covid_updated_sorted_fatality = covid_updated.sort_values(by='case_fatality_rate', axis=0, ascending=False)
covid_updated_sorted_fatality
# Out:
#            state           county  population  cases  cases_per_100k  deaths  \
# 1784  New Mexico   Harding County         625     14     2240.000000       2
# 434      Georgia  Glascock County        2971    176     5923.931336      19
# 1670    Nebraska     Grant County         623     41     6581.059390       4
# 528      Georgia    Wilcox County        8635    610     7064.273306      50
# 417      Georgia     Dodge County       20605   1428     6930.356710     114
# ...          ...              ...         ...    ...             ...     ...
# 257     Colorado  Hinsdale County         820     52     6341.463415       0
# 1637    Nebraska    Blaine County         465     21     4516.129032       0
# 1311   Minnesota      Cook County        5463    206     3770.821893       0
# 219   California    Sierra County        3005    123     4093.178037       0
# 533       Hawaii   Kalawao County          86      0        0.000000       0
#
#       deaths_per_100k  case_fatality_rate
# 1784       320.000000            0.142857
# 434        639.515315            0.107955
# 1670       642.054575            0.097561
# 528        579.038796            0.081967
# 417        553.263771            0.079832
# ...               ...                 ...
# 257          0.000000            0.000000
# 1637         0.000000            0.000000
# 1311         0.000000            0.000000
# 219          0.000000            0.000000
# 533          0.000000            0.000000
#
# [3081 rows x 8 columns]

# %% [markdown]
# <div class='exercise'><b>Reflection:</b> Data Analysis allows us to better understand a system or scenario.
# </div>

# %% [markdown]
# <div class='exercise'><b>Exercise 3.6.1 [2 pts] Trends</b>
#
# Having looked at the results from Exercises 3.3, 3.4, and 3.5, what are some trends you've noticed and any conclusions you have? (2-3 sentences)?</div>

# %% [markdown]
# <div style='background-color:#F6FEFA;padding:15px'>
#
# In 3.3, the state with lowest number of deaths is Hawaii with 152 deaths, 19 510 cases and 4 420 cases per 100k people. The population of Hawaii is 441 309.
# Whereas, in 3.3 the state with the highest number of deaths is California, with 66 016 deaths, 4 321 742 cases and 11 187 cases per 100k people. The population of California is 38 630 674.
#
# In 3.4 the state with the lowest COVID death rate is Hawai with a rate of 1 out of 2903 people that died. The highest was Mississipi, with 1 out of 328 people.
#
# In 3.5 we computed the case fatality rate per state, and we can see that the highest fatality rate is in New Mexico with 0.14 - however the deaths were just 2.
# The state with the lowest case fatality is 0, Hawaii - which is in line with the two aforementioned results.
#
# Overall the trend noticed is that the higher the cases and the higher cases per 100k people are,  the higher the deaths and deaths per 100k people. However, it is not necessarily the case that the higher the case fatality rate is, the higher also the other variables (deaths, cases, deaths per 100k or cases per 100k). See the example of New Mexico mentioned above. We believe that country fatility rates and deaths is greatly ffected by the specifics of each country and the culture.
#
#
#
# </div>

# %% [markdown]
# <div class='exercise'><b>Exercise 3.6.2 [2 pts]: Data Reliability</b>
#
# Having looked at the results from Exercise 3.5 (i.e., `covid_updated` DataFrame), do you think the original data is reliable and accurate? Are there any potential biases that you're aware of or concerned about? Please explain (3-5 sentences).</div>

# %% [markdown]
# <div style='background-color:#F6FEFA;padding:15px'>
#
# In 3.5 we computed the case fatality rate. Although it is the highest in New Mexico with 0.1328, this piece of information alone is not a reliable point of reference to understand the gravity of the effects of the pandemic in a given state. From 3.3 and 3.4 we can see that California (with 66 016 deaths) and Mississipi (with 9 061 deaths)  have been impacted by the pandemic significantly more than New Mexico (with 2 deaths).
# As a consequence, the case fatality rate can not be observed on its own. Consider the difference in domentionality between the population_dict and our main data, we would agrue that the source is not reliable.
#
#
# </div>

# %% [markdown]
# <div class='exercise'><b>Exercise 3.6.3 [1 pt]: Relationships Between Variables</b>
#
# If a county has 15 confirmed deaths, how many cases would you expect? What would you expect its population to be? Explain why (1-2 sentences in total)?
#
# **NOTE:** For this question, we aren't evaluating the accuracy of your answer but your thought-process and reasoning.
# </div>

# %% [markdown]
# <div style='background-color:#F6FEFA;padding:15px'>
#
# To estimate cases from deaths, you would need some notion of case fatality rate. We have this figure in a column in the data, by county. But for a single county, we could use the fatality rate of nearby counties (say, the average case fatality rate for counties in the same state), and use that ratio to estimate the total number of cases. We wouldn't want to use the national rate because it can vary greatly over space, as we have shown in the exercise.
#
#
# </div>

# %% [markdown]
# <div class='exercise'><b>Exercise 3.6.4 [1 pt]: Further Questions</b>
#
# What further questions do you wish to answer about COVID, including ones that may not be possible to answer from this data alone (e.g., Is there a correlation between the average age of people in a county and the # of COVID deaths)? Write at least 3 of your questions.</div>

# %% [markdown]
# <div style='background-color:#F6FEFA;padding:15px'>
#
# It would be interesting to look at data related to other factors in the pandemic, such as:
#
#     - correlation of masks sales and number of cases per 100k people in each state. We expect that the higher the masks sales and usage, the less the cases. It would be interesting to look at this.
#
#     - correlation of average salary and number of cases. The higher the average salary of a state, the more likely it is that the main industry of that state is finance or tech, where there is the possility to work from home - hence less contagion opportunities. It would be interesting to see if this expecation is met by looking at salaries alongside with deaths and cases.
#
#     - It would be interesting to look at the number of people using public transports in a given state, and see if there is a correlation between cases and deaths where the usage of public transport is more common. E.g. We assume that the usage of underground is more common in the state of NY rather than in the state of Texas. It would be interesting to look if these are correlated and if this expectation is met.
#
#
# </div>

# %% [markdown]
# ## 4. MORE DATA (25 pts)
# In order to better understand how COVID (and the testing thereof) has impacted our world, we could look at how it relates to demographics, income, education, health, and political voting. For this exercise, we will make use of `election2020_by_county.csv`.

# %% [markdown]
# <div class='exercise'><b>Exercise 4.1 [4 pts]: Load more data</b>
#
# Complete the `merge_data()` function, which should:
# 1. First, load `election2020_by_county.csv` as a new DataFrame.
# 2. Then, using the state and county names (case-sensitive) in both DataFrames, merge this new DataFrame with your existing `covid_updated`.
# 3. Return the merged DataFrame
#
# The returned `merged` DataFrame should contain all 8 columns from `covid_updated`:
# - county
# - state
# - \# total covid cases
# - \# covid cases per 100k
# - \# covid deaths
# - population
# - \# covid deaths per 100k
# - case_fatality_rate
#
# along with these 15 columns from `election2020_by_county.csv`:
# - hispanic
# - minority
# - female
# - unemployed
# - income
# - nodegree
# - bachelor
# - inactivity
# - obesity
# - density
# - cancer
# - voter_turnout
# - voter_gap
# - trump
# - biden
#
# **NOTES:**
# - We are dropping two columns from `election2020_by_county.csv`:
#     - fipscode
#     - population
# - Do not attempt to manually fix any of the state or county names. That is, **our merging should require the state and county names to be identical (case-sensitive) between the two DataFrames.** If there is a discrepancy between the two, do not worry about adjusting these names to find a perfect match.
#
# **HINT:** there are many ways to solve this, but you may find the [pandas.merge()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html) function can be really helpful
#
# **EXTRA INFORMATION:** In case you're wondering what the different features/columns are in `election2020_by_county.csv`:
#
# - state: the state in which the county lies
# - fipscode: an ID to identify each county
# - county: the name of each county
# - population: total population
# - hispanic: percent of adults that are hispanic
# - minority: percent of adults that are nonwhite
# - female: percent of adults that are female
# - unemployed: unemployment rate, as a percent
# - income: median income
# - nodegree: percent of adults who have not completed high school
# - bachelor: percent of adults with a bachelor’s degree
# - inactive: percent of adults who do not exercise in their leisure time
# - obesity: percent of adults with BMI > 30
# - density: population density, persons per square mile of land
# - cancer: prevalence of cancer per 100,000 individuals
# - voter_turnout: percentage of voting age population that voted
# - voter_gap: percentage point gap in 2020 presidential voting: trump-briden
# </div>

# %%
def merge_data(df, filepath):
    
    # YOUR CODE HERE
    election_df = pd.read_csv(filepath)
    election_df = election_df.drop(['fipscode', 'population'], axis = 1)

    merged = pd.merge(df, election_df,
                      left_on = ['state','county'], right_on = ['state','county'])

    # END OF YOUR CODE HERE
    return merged

# %% [markdown]
# Run the cell below (no changes necessary) to execute your code above

# %%
merged = merge_data(covid_updated, 'election2020_by_county.csv')

# %%
merged.head()
# Out:
#         state            county  population  cases  cases_per_100k  deaths  \
# 0    Nebraska      Hayes County         922     61     6616.052061       0
# 1    Nebraska     Harlan County        3380    219     6479.289941       0
# 2        Utah      Wayne County        2711    186     6860.936924       0
# 3  Washington   San Juan County       17582    277     1575.474918       0
# 4    Nebraska  Keya Paha County         806     54     6699.751861       0
#
#    deaths_per_100k  case_fatality_rate  hispanic  minority  ...  nodegree  \
# 0              0.0                 0.0       5.9       6.2  ...      11.8
# 1              0.0                 0.0       3.7       5.8  ...       9.3
# 2              0.0                 0.0       5.4       8.2  ...       5.7
# 3              0.0                 0.0       6.0      11.0  ...       4.9
# 4              0.0                 0.0       1.1       2.2  ...       8.0
#
#    bachelor  inactivity  obesity  density  cancer  voter_turnout  voter_gap  \
# 0      19.0        28.3     33.2      6.2   361.1      28.129206       86.1
# 1      14.5        26.7     32.1     16.8   204.0      28.086535       69.2
# 2      26.5        21.0     22.8     56.9   153.8      15.911486       52.9
# 3      45.2        15.1     20.7     90.7   222.4       4.474074      -51.3
# 4      15.8        30.2     29.6      7.9   256.3       8.000000       80.7
#
#    trump  biden
# 0   92.5    6.4
# 1   83.8   14.6
# 2   75.6   22.7
# 3   23.2   74.5
# 4   90.0    9.3
#
# [5 rows x 23 columns]

# %%
merged.shape
# Out:
# (3012, 23)

# %% [markdown]
# As mentioned above, the merging requires exact matching between the two DataFrames' `state` and `county` columns. Thus, some mismatches will occur, yielding our `merged` DataFrame to have fewer rows than `covid_updated` and `election2016_by_county.csv`.

# %% [markdown]
# <div class='exercise'><b>Data Construction / Understanding</b>
# </div>

# %% [markdown]
# <div class='exercise'><b>Exercise 4.2.1 [1 pt]: Lost Rows</b>
#
# Compared to `covid_updated`, how many rows were lost during this merging process to create `merged`? Running the cell below should print to the screen your answer.
# </div>

# %%
# YOUR CODE HERE
print(str(covid_updated.shape[0] - merged.shape[0]) + " rows were lost in the merge")


# END OF YOUR CODE HERE
# Out:
# 69 rows were lost in the merge

# %% [markdown]
# <div class='exercise'><b>Exercise 4.2.2 [2 pts]: Lost Counties</b>
#
# List the county and state of *at least 3* such rows that exist in `covid_updated` but didn't make it into `merged`. Running the cell below should print to the screen your answer.
# </div>

# %%
# YOUR CODE HERE

# Since some counties in different states have the same name, we need both
# state and county name to uniquely id them. Concatenate and compare
covid_updated_countieslist = covid_updated['county'] + ", " + covid_updated['state']
merged_countieslist = merged['county'] + ", " + merged['state']

# find the set difference
set(covid_updated_countieslist) - set(merged_countieslist)

# END OF YOUR CODE HERE
# Out:
# {'Acadia Parish, Louisiana',
#  'Aleutians West Census Area, Alaska',
#  'Allen Parish, Louisiana',
#  'Ascension Parish, Louisiana',
#  'Assumption Parish, Louisiana',
#  'Avoyelles Parish, Louisiana',
#  'Beauregard Parish, Louisiana',
#  'Bienville Parish, Louisiana',
#  'Bossier Parish, Louisiana',
#  'Caddo Parish, Louisiana',
#  'Calcasieu Parish, Louisiana',
#  'Caldwell Parish, Louisiana',
#  'Cameron Parish, Louisiana',
#  'Catahoula Parish, Louisiana',
#  'Claiborne Parish, Louisiana',
#  'Concordia Parish, Louisiana',
#  'De Soto Parish, Louisiana',
#  'Doña Ana County, New Mexico',
#  'East Baton Rouge Parish, Louisiana',
#  'East Carroll Parish, Louisiana',
#  'East Feliciana Parish, Louisiana',
#  'Evangeline Parish, Louisiana',
#  'Franklin Parish, Louisiana',
#  'Grant Parish, Louisiana',
#  'Iberia Parish, Louisiana',
#  'Iberville Parish, Louisiana',
#  'Jackson Parish, Louisiana',
#  'Jefferson Davis Parish, Louisiana',
#  'Jefferson Parish, Louisiana',
#  'Kalawao County, Hawaii',
#  'Kusilvak Census Area, Alaska',
#  'Lafayette Parish, Louisiana',
#  'Lafourche Parish, Louisiana',
#  'Lincoln Parish, Louisiana',
#  'Livingston Parish, Louisiana',
#  'Madison Parish, Louisiana',
#  'Morehouse Parish, Louisiana',
#  'Natchitoches Parish, Louisiana',
#  'Oglala Lakota County, South Dakota',
#  'Orleans Parish, Louisiana',
#  'Ouachita Parish, Louisiana',
#  'Plaquemines Parish, Louisiana',
#  'Pointe Coupee Parish, Louisiana',
#  'Rapides Parish, Louisiana',
#  'Red River Parish, Louisiana',
#  'Richland Parish, Louisiana',
#  'Sabine Parish, Louisiana',
#  'Southeast Fairbanks Census Area, Alaska',
#  'St. Bernard Parish, Louisiana',
#  'St. Charles Parish, Louisiana',
#  'St. Helena Parish, Louisiana',
#  'St. James Parish, Louisiana',
#  'St. John the Baptist Parish, Louisiana',
#  'St. Landry Parish, Louisiana',
#  'St. Martin Parish, Louisiana',
#  'St. Mary Parish, Louisiana',
#  'St. Tammany Parish, Louisiana',
#  'Tangipahoa Parish, Louisiana',
#  'Tensas Parish, Louisiana',
#  'Terrebonne Parish, Louisiana',
#  'Union Parish, Louisiana',
#  'Vermilion Parish, Louisiana',
#  'Vernon Parish, Louisiana',
#  'Washington Parish, Louisiana',
#  'Webster Parish, Louisiana',
#  'West Baton Rouge Parish, Louisiana',
#  'West Carroll Parish, Louisiana',
#  'West Feliciana Parish, Louisiana',
#  'Winn Parish, Louisiana'}

# %% [markdown]
# <div class='exercise'><b>Exercise 4.2.3 [2 pts]: Suggested Fixes</b>
#
# If we needed to be highly thorough and needed comprehensive data coverage, do you have any suggestions on how we could quickly, soundly fix most or all of them? (Write 2-3 sentences.)
#
# <b>NOTE: Please do not actually fix these mismatches; for this Exercise, it's okay that the `merged` DataFrame is smaller than `covid_updated`</b>
# </div>

# %% [markdown]
# <div style='background-color:#F6FEFA;padding:15px'>
#
# First, we should perform a "left" join rather than an "inner" join, as that will preserve the size of the larger dataframe (assuming the larger dataframe is on the left). We could populate cells with missing values as NA if the data are truly missing. If the data are missing because the join failed on state and county names, then we would need to fix the names. The best way to do this would not be to clean the names, but rather to use a unique identifier which is a string of numerals, which are easier to maintain than text (not case sensitive, for instance). We should use fips codes in this case. Finally, if we really wanted to get rid of NAs we could impute values using the values of neighboring counties, but I don't think that would lead to very reliable results.
#
# </div>

# %% [markdown]
# This past example demonstrates how easy it is for data to become messy. It also shows the importance of paying close attention to your data in order to understand what you are working with.

# %% [markdown]
# Our `case_fatality_rate` column can be viewed as an approximation of how effective and thorough *COVID testing* is for a given county.
#
# Our `# covid deaths` column can be viewed as an extreme indication of how severe *COVID* has impacted a given county.
#
# Our `# covid cases per 100k` column be viewed as middle-ground between the two aforementioned features. That is, it measures the impact of the disease and is influenced by the thoroughness of COVID testing.
#
# Using these three informative features, we can inspect how impacted each county is, while correlating this with other features of each county, such as income-level, health metrics, demographics, etc.

# %% [markdown]
# <div class='exercise'><b>Exercise 4.3 [2 pts]: Cleaning the data</b>
#
# Before we do any further analysis, we first notice that some counties haven't encountered a single COVID death (usually ones with very small populations), thus providing us with little information. Write code in the cell below to update the `merged` DataFrame so that all rows with 0 deaths are removed.

# %%
# YOUR CODE HERE
merged = merged.loc[merged['deaths'] != 0]
merged
# END OF YOUR CODE HERE
# Out:
#               state           county  population  cases  cases_per_100k  \
# 32         Nebraska    Saline County       14224   2044    14370.078740
# 33         Colorado      Lake County        8127    938    11541.774332
# 34        Minnesota     Dodge County       20934   2369    11316.518582
# 35         Colorado    Pitkin County       17767   2918    16423.706872
# 36    West Virginia   Calhoun County        7109    725    10198.340132
# ...             ...              ...         ...    ...             ...
# 3006        Georgia     Dodge County       20605   1428     6930.356710
# 3007        Georgia    Wilcox County        8635    610     7064.273306
# 3008       Nebraska     Grant County         623     41     6581.059390
# 3009        Georgia  Glascock County        2971    176     5923.931336
# 3010     New Mexico   Harding County         625     14     2240.000000
#
#       deaths  deaths_per_100k  case_fatality_rate  hispanic  minority  ...  \
# 32         2        14.060742            0.000978      24.3      29.3  ...
# 33         1        12.304663            0.001066      33.9      35.7  ...
# 34         3        14.330754            0.001266       4.9       7.5  ...
# 35         4        22.513649            0.001371       9.8      14.3  ...
# 36         1        14.066676            0.001379       1.3       2.7  ...
# ...      ...              ...                 ...       ...       ...  ...
# 3006     114       553.263771            0.079832       3.4      34.7  ...
# 3007      50       579.038796            0.081967       4.3      41.5  ...
# 3008       4       642.054575            0.097561       1.9       3.8  ...
# 3009      19       639.515315            0.107955       1.6      12.6  ...
# 3010       2       320.000000            0.142857      37.4      37.7  ...
#
#       nodegree  bachelor  inactivity  obesity  density  cancer  voter_turnout  \
# 32        17.1      14.3        31.0     33.0      1.5   309.1      40.293874
# 33         7.4      30.3        15.1     17.5     19.4   112.4      29.853937
# 34         6.5      24.1        18.3     24.9    709.0   140.3      17.427640
# 35         5.2      56.4         8.9     14.9     17.7    70.8      12.694664
# 36        24.2       8.9        30.2     32.7     27.3   304.8      50.167729
# ...        ...       ...         ...      ...      ...     ...            ...
# 3006      20.4      14.4        28.8     28.5     44.0   212.3      51.126453
# 3007      23.9       8.7        27.7     31.5     24.5   248.4      53.295374
# 3008       4.9      18.6        30.6     28.3      4.5   305.1      23.574144
# 3009      17.5      11.4        24.8     28.6     21.4   264.6      32.529082
# 3010      10.8      23.9        24.0     22.9      1.5   195.3     -13.483146
#
#       voter_gap  trump  biden
# 32         28.5   62.9   34.4
# 33        -20.2   37.9   58.1
# 34         30.5   64.0   33.5
# 35        -52.1   23.2   75.3
# 36         60.5   79.6   19.1
# ...         ...    ...    ...
# 3006       45.5   72.4   26.9
# 3007       46.9   73.2   26.3
# 3008       88.3   93.3    5.0
# 3009       79.7   89.6    9.9
# 3010       27.8   63.2   35.4
#
# [2979 rows x 23 columns]

# %% [markdown]
# Running `.describe()` allows us to quickly see summary statistics of our DataFrame

# %%
merged.describe()
# Out:
#          population         cases  cases_per_100k        deaths  \
# count  2.979000e+03  2.979000e+03     2979.000000   2979.000000
# mean   1.062667e+05  1.306454e+04    12718.303864    208.533736
# std    3.406025e+05  4.436774e+04     3685.969573    781.506718
# min    4.040000e+02  1.400000e+01     2240.000000      1.000000
# 25%    1.121350e+04  1.387000e+03    10429.252076     24.000000
# 50%    2.627100e+04  3.320000e+03    12670.670293     57.000000
# 75%    6.874050e+04  8.663000e+03    14875.162049    137.500000
# max    1.003911e+07  1.371196e+06    72727.272727  25693.000000
#
#        deaths_per_100k  case_fatality_rate     hispanic     minority  \
# count      2979.000000         2979.000000  2978.000000  2978.000000
# mean        228.538832            0.018296     9.269913    22.521760
# std         119.066874            0.009811    13.934891    19.803921
# min           8.299559            0.000978     0.000000     0.200000
# 25%         143.403732            0.012181     2.000000     6.900000
# 50%         212.222061            0.016479     4.000000    15.200000
# 75%         293.301885            0.022418     9.500000    33.700000
# max         865.800866            0.142857    99.200000    99.400000
#
#             female   unemployed  ...     nodegree     bachelor   inactivity  \
# count  2978.000000  2979.000000  ...  2979.000000  2979.000000  2979.000000
# mean     49.920151     5.488587  ...    14.979859    19.993622    25.969151
# std       2.357593     1.955033  ...     6.746965     8.729129     5.157168
# min      19.166215     1.800000  ...     1.900000     4.400000     8.100000
# 25%      49.465408     4.100000  ...     9.900000    14.000000    22.700000
# 50%      50.384479     5.300000  ...    13.500000    17.900000    25.800000
# 75%      51.069106     6.500000  ...    19.200000    23.600000    29.400000
# max      56.633907    24.000000  ...    53.300000    72.000000    41.400000
#
#            obesity       density       cancer  voter_turnout    voter_gap  \
# count  2979.000000   2979.000000  2938.000000    2947.000000  2946.000000
# mean     30.993689    230.500705   228.605242      35.514568    33.039477
# std       4.452694   1712.483148    55.843412      13.829715    30.882108
# min      11.800000      0.100000    46.200000    -168.323353   -90.000000
# 25%      28.400000     17.300000   193.500000      27.701651    15.450000
# 50%      31.200000     45.000000   230.350000      35.049804    39.300000
# 75%      33.800000    110.350000   265.075000      42.476078    56.875000
# max      47.600000  69468.400000   458.300000     100.000000    93.100000
#
#              trump        biden
# count  2946.000000  2946.000000
# mean     65.658282    32.618805
# std      15.504336    15.387119
# min       4.000000     3.100000
# 25%      56.825000    20.800000
# 50%      68.800000    29.500000
# 75%      77.575000    41.500000
# max      96.200000    94.000000
#
# [8 rows x 21 columns]

# %% [markdown]
# Using the information reported from `.describe()`, we can imagine dividing our DataFrame into 4 separate bins, based on the distribution for any given feature. Specifically, based on a particular feature:
# - the $1^{st}$ bin will be the data that has values between the **min** and **25%**
# - the $2^{nd}$ bin will be the data that has values between **25%** and **50%**
# - the $3^{rd}$ bin will be the data that has values between **50%** and **75%**
# - the $4^{th}$ bin will be the data that has values between **75%** and **max**
#
# <div class='exercise'><b>Exercise 4.4 [3 pts]: Partitioning our data</b>
#
# Complete the `partition_df()` function, which takes as input:
# - DataFrame to work with
# - feature (e.g., obesity) to filter by
# - minimum value
# - maximum value
#
# and outputs:
# - a subset of the DataFrame that has values between the passed-in minimum and maximum values (inclusively) for the passed-in feature.
#
# For example, if we called `partition_df(merged, 'obesity', 30, 45)`, it should return a subset of the `merged` DataFrame that has obesity values between 30 and 45 (and including the boundary values of 30 and 45).
# </div>

# %%
def partition_df(df, column_name, minv, maxv):
    # YOUR CODE HERE
    partitioned = df.loc[(df[column_name] > minv) & (df[column_name] < maxv)]
    return partitioned
    # END OF YOUR CODE HERE

# %%
partition_df(merged, 'obesity', 30, 45)
# Out:
#               state            county  population  cases  cases_per_100k  \
# 32         Nebraska     Saline County       14224   2044    14370.078740
# 36    West Virginia    Calhoun County        7109    725    10198.340132
# 37         Nebraska  Jefferson County        7046    669     9494.748794
# 38         Kentucky    Elliott County        7517   1208    16070.240788
# 39        Minnesota    Wabasha County       21627   2378    10995.514866
# ...             ...               ...         ...    ...             ...
# 3000        Georgia    Telfair County       15860    916     5775.535939
# 3001        Georgia    Terrell County        8531    752     8814.910327
# 3003        Georgia    Hancock County        8457    981    11599.858106
# 3004        Georgia     Twiggs County        8120    701     8633.004926
# 3007        Georgia     Wilcox County        8635    610     7064.273306
#
#       deaths  deaths_per_100k  case_fatality_rate  hispanic  minority  ...  \
# 32         2        14.060742            0.000978      24.3      29.3  ...
# 36         1        14.066676            0.001379       1.3       2.7  ...
# 37         1        14.192450            0.001495       3.6       5.8  ...
# 38         2        26.606359            0.001656       0.3       3.9  ...
# 39         4        18.495399            0.001682       2.9       5.1  ...
# ...      ...              ...                 ...       ...       ...  ...
# 3000      62       390.920555            0.067686      11.6      50.9  ...
# 3001      53       621.263627            0.070479       2.7      64.5  ...
# 3003      71       839.541208            0.072375       1.8      75.9  ...
# 3004      51       628.078818            0.072753       0.4      45.1  ...
# 3007      50       579.038796            0.081967       4.3      41.5  ...
#
#       nodegree  bachelor  inactivity  obesity  density  cancer  voter_turnout  \
# 32        17.1      14.3        31.0     33.0      1.5   309.1      40.293874
# 36        24.2       8.9        30.2     32.7     27.3   304.8      50.167729
# 37        10.5      13.2        28.0     36.2     11.0   230.7      33.996448
# 38        26.4       6.4        34.0     33.7     40.2   263.5      51.030085
# 39         7.3      20.7        21.5     32.2      6.2   317.1      21.197353
# ...        ...       ...         ...      ...      ...     ...            ...
# 3000      25.7      10.8        29.0     30.9     37.7   187.9      62.239651
# 3001      31.6      10.1        27.8     31.6     27.8   258.2      34.809566
# 3003      27.6      10.6        27.8     31.2     20.0   232.5      42.757009
# 3004      31.2       9.6        29.6     32.8     25.2   234.8      33.253229
# 3007      23.9       8.7        27.7     31.5     24.5   248.4      53.295374
#
#       voter_gap  trump  biden
# 32         28.5   62.9   34.4
# 36         60.5   79.6   19.1
# 37         43.1   70.4   27.3
# 38         51.2   75.0   23.8
# 39         26.4   62.3   35.9
# ...         ...    ...    ...
# 3000       30.9   65.2   34.3
# 3001       -8.4   45.4   53.8
# 3003      -43.9   27.8   71.7
# 3004        7.3   53.3   46.0
# 3007       46.9   73.2   26.3
#
# [1811 rows x 23 columns]

# %% [markdown]
# <div class='exercise'><b>Exercise 4.5: [4 pts] Exploratory Data Analysis</b>
#
# Identify a few features that you're interested in, and inspect if there's any correlation with the COVID data. Specifically, simply run your `partition_df()` function below, many times, each with a different subset of the data -- select a range of values and a particular feature. For example, if I'm interested in __cancer__, I could look at the 4 quartiles (per `.describe()`) and use those ranges of values as I repeatedly execute `partition_df()`. For this exercise, after running the function several times, **write 3-5 sentences about any patterns or correlations you noticed or didn't notice but expected to find.**
# </div>

# %%
# YOUR CODE HERE
merged.describe()
# END OF YOUR CODE HERE

#partition_df(merged, 'your feature here', your_min_value, your_max_va).describe()
# Out:
#          population         cases  cases_per_100k        deaths  \
# count  2.979000e+03  2.979000e+03     2979.000000   2979.000000
# mean   1.062667e+05  1.306454e+04    12718.303864    208.533736
# std    3.406025e+05  4.436774e+04     3685.969573    781.506718
# min    4.040000e+02  1.400000e+01     2240.000000      1.000000
# 25%    1.121350e+04  1.387000e+03    10429.252076     24.000000
# 50%    2.627100e+04  3.320000e+03    12670.670293     57.000000
# 75%    6.874050e+04  8.663000e+03    14875.162049    137.500000
# max    1.003911e+07  1.371196e+06    72727.272727  25693.000000
#
#        deaths_per_100k  case_fatality_rate     hispanic     minority  \
# count      2979.000000         2979.000000  2978.000000  2978.000000
# mean        228.538832            0.018296     9.269913    22.521760
# std         119.066874            0.009811    13.934891    19.803921
# min           8.299559            0.000978     0.000000     0.200000
# 25%         143.403732            0.012181     2.000000     6.900000
# 50%         212.222061            0.016479     4.000000    15.200000
# 75%         293.301885            0.022418     9.500000    33.700000
# max         865.800866            0.142857    99.200000    99.400000
#
#             female   unemployed  ...     nodegree     bachelor   inactivity  \
# count  2978.000000  2979.000000  ...  2979.000000  2979.000000  2979.000000
# mean     49.920151     5.488587  ...    14.979859    19.993622    25.969151
# std       2.357593     1.955033  ...     6.746965     8.729129     5.157168
# min      19.166215     1.800000  ...     1.900000     4.400000     8.100000
# 25%      49.465408     4.100000  ...     9.900000    14.000000    22.700000
# 50%      50.384479     5.300000  ...    13.500000    17.900000    25.800000
# 75%      51.069106     6.500000  ...    19.200000    23.600000    29.400000
# max      56.633907    24.000000  ...    53.300000    72.000000    41.400000
#
#            obesity       density       cancer  voter_turnout    voter_gap  \
# count  2979.000000   2979.000000  2938.000000    2947.000000  2946.000000
# mean     30.993689    230.500705   228.605242      35.514568    33.039477
# std       4.452694   1712.483148    55.843412      13.829715    30.882108
# min      11.800000      0.100000    46.200000    -168.323353   -90.000000
# 25%      28.400000     17.300000   193.500000      27.701651    15.450000
# 50%      31.200000     45.000000   230.350000      35.049804    39.300000
# 75%      33.800000    110.350000   265.075000      42.476078    56.875000
# max      47.600000  69468.400000   458.300000     100.000000    93.100000
#
#              trump        biden
# count  2946.000000  2946.000000
# mean     65.658282    32.618805
# std      15.504336    15.387119
# min       4.000000     3.100000
# 25%      56.825000    20.800000
# 50%      68.800000    29.500000
# 75%      77.575000    41.500000
# max      96.200000    94.000000
#
# [8 rows x 21 columns]

# %%
partition_df(merged, 'trump', 0, 56.825).describe()
# Out:
#          population         cases  cases_per_100k        deaths  \
# count  7.370000e+02  7.370000e+02      737.000000    737.000000
# mean   2.999259e+05  3.571548e+04    11670.482174    566.693351
# std    6.342038e+05  8.358019e+04     3851.657467   1489.287555
# min    7.280000e+02  8.600000e+01     2484.334583      1.000000
# 25%    2.499400e+04  2.674000e+03     9239.508463     45.000000
# 50%    9.252500e+04  9.456000e+03    11633.827762    129.000000
# 75%    3.183160e+05  3.477500e+04    13969.206159    518.000000
# max    1.003911e+07  1.371196e+06    40909.507656  25693.000000
#
#        deaths_per_100k  case_fatality_rate    hispanic    minority  \
# count       737.000000          737.000000  737.000000  737.000000
# mean        199.624832            0.016851   13.700678   38.312483
# std         125.321563            0.009066   18.867704   23.722498
# min           8.299559            0.001066    0.000000    2.500000
# 25%         106.760905            0.010726    3.000000   17.400000
# 50%         169.546677            0.015170    6.200000   35.700000
# 75%         262.346858            0.020744   15.000000   56.800000
# max         839.541208            0.072753   99.200000   99.400000
#
#            female  unemployed  ...    nodegree    bachelor  inactivity  \
# count  737.000000  737.000000  ...  737.000000  737.000000  737.000000
# mean    50.399151    5.927680  ...   14.143555   26.888738   22.878697
# std      2.169557    2.336192  ...    7.864929   11.611929    5.651173
# min     32.813627    2.200000  ...    1.900000    6.000000    8.100000
# 25%     49.898763    4.300000  ...    8.400000   17.900000   18.700000
# 50%     50.704225    5.400000  ...   11.800000   26.000000   22.500000
# 75%     51.500966    6.900000  ...   18.600000   34.000000   26.300000
# max     55.797167   24.000000  ...   53.300000   72.000000   38.200000
#
#           obesity       density      cancer  voter_turnout   voter_gap  \
# count  737.000000    737.000000  731.000000     737.000000  737.000000
# mean    29.451696    404.214383  216.728044      35.959351  -10.485075
# std      6.076583   1748.003627   59.201060      20.305757   20.758919
# min     11.800000      0.300000   46.200000    -168.323353  -90.000000
# 25%     25.500000     23.000000  178.500000      24.879747  -23.100000
# 50%     29.300000     63.000000  216.600000      33.241396   -6.200000
# 75%     33.200000    243.900000  252.400000      44.071825    6.600000
# max     47.600000  32903.300000  458.300000      99.552895   15.900000
#
#             trump       biden
# count  737.000000  737.000000
# mean    43.819132   54.304206
# std     10.353074   10.425191
# min      4.000000   40.700000
# 25%     37.500000   45.900000
# 50%     45.900000   52.000000
# 75%     52.400000   60.500000
# max     56.800000   94.000000
#
# [8 rows x 21 columns]

# %%
print("Mean cases per 100k by minority quartiles")
print("First quartile:")
print(partition_df(merged, 'minority', 0, 6.9)['cases_per_100k'].mean())
print("Second quartile:")
print(partition_df(merged, 'minority', 6.9, 15.2)['cases_per_100k'].mean())
print("Third quartile:")
print(partition_df(merged, 'minority', 15.2, 33.7)['cases_per_100k'].mean())
print("Fourth quartile:")
print(partition_df(merged, 'minority', 33.7, 100)['cases_per_100k'].mean())
print("\n")

print("Mean cases per 100k by trump quartiles")
print("First quartile:")
print(partition_df(merged, 'trump', 0, 56.825)['cases_per_100k'].mean())
print("Second quartile:")
print(partition_df(merged, 'trump', 56.825, 68.8)['cases_per_100k'].mean())
print("Third quartile:")
print(partition_df(merged, 'trump', 66.8, 77.575)['cases_per_100k'].mean())
print("Fourth quartile:")
print(partition_df(merged, 'trump', 77.575, 100)['cases_per_100k'].mean())
print("\n")

print("Mean deaths per 100k by minority quartiles")
print("First quartile:")
print(partition_df(merged, 'minority', 0, 6.9)['deaths_per_100k'].mean())
print("Second quartile:")
print(partition_df(merged, 'minority', 6.9, 15.2)['deaths_per_100k'].mean())
print("Third quartile:")
print(partition_df(merged, 'minority', 15.2, 33.7)['deaths_per_100k'].mean())
print("Fourth quartile:")
print(partition_df(merged, 'minority', 33.7, 100)['deaths_per_100k'].mean())
print("\n")

print("Mean deaths per 100k by trump quartiles")
print("First quartile:")
print(partition_df(merged, 'trump', 0, 56.825)['deaths_per_100k'].mean())
print("Second quartile:")
print(partition_df(merged, 'trump', 56.825, 68.8)['deaths_per_100k'].mean())
print("Third quartile:")
print(partition_df(merged, 'trump', 66.8, 77.575)['deaths_per_100k'].mean())
print("Fourth quartile:")
print(partition_df(merged, 'trump', 77.575, 100)['deaths_per_100k'].mean())
print("\n")

print("Mean cases per 100k by biden quartiles")
print("First quartile:")
print(partition_df(merged, 'biden', 0, 20.8)['cases_per_100k'].mean())
print("Second quartile:")
print(partition_df(merged, 'biden', 20.8, 29.5)['cases_per_100k'].mean())
print("Third quartile:")
print(partition_df(merged, 'biden', 29.5, 41.5)['cases_per_100k'].mean())
print("Fourth quartile:")
print(partition_df(merged, 'biden', 41.5, 100)['cases_per_100k'].mean())
print("\n")

print("Mean deaths per 100k by biden quartiles")
print("First quartile:")
print(partition_df(merged, 'biden', 0, 20.8)['deaths_per_100k'].mean())
print("Second quartile:")
print(partition_df(merged, 'biden', 20.8, 29.5)['deaths_per_100k'].mean())
print("Third quartile:")
print(partition_df(merged, 'biden', 29.5, 41.5)['deaths_per_100k'].mean())
print("Fourth quartile:")
print(partition_df(merged, 'biden', 41.5, 100)['deaths_per_100k'].mean())

# END OF YOUR CODE HERE

#partition_df(merged, 'your feature here', your_min_value, your_max_va).describe()
# Out:
# Mean cases per 100k by minority quartiles
# First quartile:
# 12127.819625593467
# Second quartile:
# 12563.894296664117
# Third quartile:
# 12581.44753985462
# Fourth quartile:
# 13597.05228555903
#
#
# Mean cases per 100k by trump quartiles
# First quartile:
# 11670.482174088746
# Second quartile:
# 12474.431148446498
# Third quartile:
# 13294.444933828107
# Fourth quartile:
# 13423.834664229142
#
#
# Mean deaths per 100k by minority quartiles
# First quartile:
# 223.30402151766154
# Second quartile:
# 204.20720269002044
# Third quartile:
# 210.62770298008098
# Fourth quartile:
# 276.5963333264724
#
#
# Mean deaths per 100k by trump quartiles
# First quartile:
# 199.62483211911442
# Second quartile:
# 212.9376082465337
# Third quartile:
# 238.9126587229542
# Fourth quartile:
# 263.4544128785315
#
#
# Mean cases per 100k by biden quartiles
# First quartile:
# 13342.03793251125
# Second quartile:
# 13480.050240967877
# Third quartile:
# 12419.222386472873
# Fourth quartile:
# 11682.712405442226
#
#
# Mean deaths per 100k by biden quartiles
# First quartile:
# 259.7921344572366
# Second quartile:
# 241.86001434488267
# Third quartile:
# 214.9335294779903
# Fourth quartile:
# 202.46086045985814

# %% [markdown]
# <div style='background-color:#F6FEFA;padding:15px'>
#
# **Here we can notice that the latter the quartiles per the biden variable (i.e. the more people voted for Biden), the lower the mean deaths and cases. Hinting at how on average states and counties that are more Democrats might have taken the pandemic more seriously (e.g. masks usage, social distancing), and hence had a lower amount of deaths and cases on average. The opposite is the case for the variable trump. The latter the quartiles, i.e. the more people voted for Trump, the higher the average of deaths and cases.
#     Additionally, the higher the minority presence is, the higher the average of cases and deaths are present as well.**
# </div>

# %% [markdown]
# `.describe()` provides these nice summary statistics over any portion of data that we give it. Instead of iteratively inspecting several subsets of the data, let's actually split our DataFrame into new categories; instead of representing all features by floating point numbers, let's create new _categorical_ names for feature(s) based on their numbers. The code below does just this. It creates a new column, `income group` that has 4 possible values, each one corresponding to a quartile of the original `income` values.
#
# Run the cell below.

# %%
bins = [0, 38000, 45000, 52000, 200000]
names = ['income-group-1', 'income-group-2', 'income-group-3', 'income-group-4']
d = dict(enumerate(names, 1))
merged['income group'] = np.vectorize(d.get)(np.digitize(merged['income'], bins))
merged
# Out:
#               state           county  population  cases  cases_per_100k  \
# 32         Nebraska    Saline County       14224   2044    14370.078740
# 33         Colorado      Lake County        8127    938    11541.774332
# 34        Minnesota     Dodge County       20934   2369    11316.518582
# 35         Colorado    Pitkin County       17767   2918    16423.706872
# 36    West Virginia   Calhoun County        7109    725    10198.340132
# ...             ...              ...         ...    ...             ...
# 3006        Georgia     Dodge County       20605   1428     6930.356710
# 3007        Georgia    Wilcox County        8635    610     7064.273306
# 3008       Nebraska     Grant County         623     41     6581.059390
# 3009        Georgia  Glascock County        2971    176     5923.931336
# 3010     New Mexico   Harding County         625     14     2240.000000
#
#       deaths  deaths_per_100k  case_fatality_rate  hispanic  minority  ...  \
# 32         2        14.060742            0.000978      24.3      29.3  ...
# 33         1        12.304663            0.001066      33.9      35.7  ...
# 34         3        14.330754            0.001266       4.9       7.5  ...
# 35         4        22.513649            0.001371       9.8      14.3  ...
# 36         1        14.066676            0.001379       1.3       2.7  ...
# ...      ...              ...                 ...       ...       ...  ...
# 3006     114       553.263771            0.079832       3.4      34.7  ...
# 3007      50       579.038796            0.081967       4.3      41.5  ...
# 3008       4       642.054575            0.097561       1.9       3.8  ...
# 3009      19       639.515315            0.107955       1.6      12.6  ...
# 3010       2       320.000000            0.142857      37.4      37.7  ...
#
#       bachelor  inactivity  obesity  density  cancer  voter_turnout  \
# 32        14.3        31.0     33.0      1.5   309.1      40.293874
# 33        30.3        15.1     17.5     19.4   112.4      29.853937
# 34        24.1        18.3     24.9    709.0   140.3      17.427640
# 35        56.4         8.9     14.9     17.7    70.8      12.694664
# 36         8.9        30.2     32.7     27.3   304.8      50.167729
# ...        ...         ...      ...      ...     ...            ...
# 3006      14.4        28.8     28.5     44.0   212.3      51.126453
# 3007       8.7        27.7     31.5     24.5   248.4      53.295374
# 3008      18.6        30.6     28.3      4.5   305.1      23.574144
# 3009      11.4        24.8     28.6     21.4   264.6      32.529082
# 3010      23.9        24.0     22.9      1.5   195.3     -13.483146
#
#       voter_gap  trump  biden    income group
# 32         28.5   62.9   34.4  income-group-3
# 33        -20.2   37.9   58.1  income-group-3
# 34         30.5   64.0   33.5  income-group-4
# 35        -52.1   23.2   75.3  income-group-4
# 36         60.5   79.6   19.1  income-group-1
# ...         ...    ...    ...             ...
# 3006       45.5   72.4   26.9  income-group-1
# 3007       46.9   73.2   26.3  income-group-1
# 3008       88.3   93.3    5.0  income-group-3
# 3009       79.7   89.6    9.9  income-group-2
# 3010       27.8   63.2   35.4  income-group-2
#
# [2979 rows x 24 columns]

# %% [markdown]
# <div class='exercise'><b>Exercise 4.6 [5 pts]: Aggregate data</b>
#
#
# Write code in the cell below to group (and display) the data according to the 4 income groups. Also, while we will still keep the same columns (i.e, features), the values of each should now represent the __average__ value of all rows that were subsumed in the making of the aggregate income-group. Your resulting DataFrame should have just 4 rows (income-group-1, income-group-2, income-group-3, income-group-4). See example in the cell below.
#
#
# Since every feature (except for `# total cases`, `# covid deaths`, and `population`) was already an average value corresponding to a particular __county__, when we aggregate our data by income groups, we are effectively taking an average of an average. Many counties are being aggregated for each income-group row. This approach isn't as accurate as possible; it would be more accurate if we re-adjusted every value so that it was truly an average that was based on the total __population__ of all counties that are subsumed within a given income-group row. That's okay, though. An average of averages will suffice for the purpose of this exercise.
# </div>

# %%
# EXAMPLE: If our `merged` DataFrame were
# COUNTY    INCOME GROUP    BACHELOR ... (other columns, too)
#   A            2             50
#   B            1             20
#   C            1             30
#   D            2             70
#   E            3             95

# it should become
# INCOME GROUP    BACHELOR ... (other columns, too)
#   1                25
#   2                60
#   3                95

# YOUR CODE HERE
merged.groupby('income group').agg('mean')



# END OF YOUR CODE HERE
# Out:
#                    population         cases  cases_per_100k      deaths  \
# income group
# income-group-1   27822.511450   3967.729771    13938.683609   85.535878
# income-group-2   64545.897909   8688.885609    12794.250094  144.731857
# income-group-3   98807.927476  12957.001395    12523.820423  193.654114
# income-group-4  220432.837531  25146.321159    11809.426796  388.764484
#
#                 deaths_per_100k  case_fatality_rate   hispanic   minority  \
# income group
# income-group-1       297.571746            0.022672   9.138779  32.366718
# income-group-2       237.898358            0.019012   8.869704  20.386946
# income-group-3       210.900509            0.016994   8.860669  18.001534
# income-group-4       177.935336            0.015128  10.156927  20.665365
#
#                    female  unemployed  ...   nodegree   bachelor  inactivity  \
# income group                           ...
# income-group-1  50.002613    7.272366  ...  21.991145  13.595420   30.101985
# income-group-2  49.813455    5.718696  ...  15.617712  17.565068   26.996187
# income-group-3  49.863219    4.852301  ...  12.760530  20.438773   25.085914
# income-group-4  50.012650    4.356045  ...  10.546977  27.356423   22.305793
#
#                   obesity     density      cancer  voter_turnout  voter_gap  \
# income group
# income-group-1  33.647328   87.845954  238.566258      41.844069  33.203988
# income-group-2  31.489914  131.076630  235.296981      37.075902  40.729543
# income-group-3  30.619386  341.441562  227.691926      34.282463  35.691831
# income-group-4  28.634509  349.803023  214.376306      29.680387  22.443742
#
#                     trump      biden
# income group
# income-group-1  65.926074  32.722086
# income-group-2  69.545117  28.815575
# income-group-3  66.912254  31.220423
# income-group-4  60.226839  37.783097
#
# [4 rows x 21 columns]

# %% [markdown]
# <div class='exercise'><b>Wrapping Up</b>
# </div>

# %% [markdown]
# <div class='exercise'><b>Exercise 4.7.1 [1 pt]: Conclusions</b>
# What are your conclusions/finding from this alternative view of the data? (2-4 sentences).
# </div>

# %% [markdown]
# <div style='background-color:#F6FEFA;padding:15px'>
#
# Here from 4.6 we can notice that the higher the income, the lower the cases per 100k and deaths per 100k, as well as the case fatality rate.
#
#
# By using this kind of visualization we could ideentify possible patterns, e.g. population with greater income have better healthcare and jobs (i.e. the opportunity to work from home and practice social distancing).
#
# On the other hand, low income families most likely work in jobs in person, putting their families and themselves at risk, possibly increasing the COVID spread and contamination rate.
#
#
# </div>

# %% [markdown]
# <div class='exercise'><b>Exercise 4.7.2 [1 pt]: Possible Weaknesses</b>
# What are some weaknesses from this view of the data? (2-4 sentences).
# </div>

# %% [markdown]
# <div style='background-color:#F6FEFA;padding:15px'>
#
# Comparing the later way of representing data with the intial ones from problem 4, we can observe that in the effort of making the representation readable, we do not include all the informations provided by the data. Thus we are in danger of missing an important correlation of data that is not related with the income of the subjects.
# </div>

# %% [markdown]
# ## Moving Forward
#
# In this homework assignment, we've focused on gathering, parsing, and exploring data. However, what if we wanted to *predict* some behavior of the data. For example, imagine one is curious how a particular county will respond to COVID. Or, imagine we looked at counties' COVID data on a weekly basis, one could be interested in predicting the upcoming week's behavior.
#
# Alternatively, one could be interested in *inference*, whereby we are more concerned with trying to understand __why__ and __how__ a system behaves the way it does. We might wish to understand which factors most correlate and cause a certain event to happen. This could give us insights into where certain inequalities persist.
#
# For both *prediction* and *inference*, our computational method of solving such a task is referred to as a model. For the remainder of CS109, we will spend significant focus on various models.
# </div>

# %% [markdown]
# ## Reflection
#
# As a reminder, this is just **one** of the homework assignments in this course, the point of which is to assess your learning and to provide both you and us with an indication as to how aligned your knowledge and skills are with our learning objectives. To this end, we encourage you to reflect on your progress, strengths, and weaknesses and to make changes, if necessary, to accomplish your goals. Likewise, please reach out to the TFs and teaching staff if you need help. We want everyone to feel comfortable in being honest about these elements, with both herself/himself and us. For these purposes, we will ask you several times throughout the semester to complete an anonymous poll.
